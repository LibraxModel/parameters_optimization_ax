# %%
import pandas as pd
import numpy as np
import json
from typing import List, Dict, Any

print("✅ 库导入完成")

# 读取实验数据
data_file = "1728_BMS_experiments_yield_and_cost.csv"
df = pd.read_csv(data_file)

print(f"�� 数据加载完成，共{len(df)}行数据")
print(f"📋 列名: {list(df.columns)}")
print("\n🔍 数据预览:")
print(df.head())
print("\n📈 数据统计:")
print(df.describe())
# Out:
# ✅ 库导入完成
# �� 数据加载完成，共1728行数据
# 📋 列名: ['new_index', 'base', 'ligand', 'solvent', 'concentration', 'temperature', 'yield', 'cost']
#
# 🔍 数据预览:
#    new_index  base      ligand solvent  concentration  temperature  yield  \
# 0          0  KOAc   BrettPhos    DMAc            0.1          105   5.47
# 1          1  KOAc     PPhtBu2    DMAc            0.1          105   0.00
# 2          2  KOAc  tBPh-CPhos    DMAc            0.1          105  78.95
# 3          3  KOAc   PCy3 HBF4    DMAc            0.1          105   7.26
# 4          4  KOAc        PPh3    DMAc            0.1          105  28.15
#
#        cost
# 0  0.145775
# 1  0.043201
# 2  0.269140
# 3  0.032181
# 4  0.026373
#
# 📈 数据统计:
#          new_index  concentration  temperature        yield         cost
# count  1728.000000    1728.000000  1728.000000  1728.000000  1728.000000
# mean    863.500000       0.103333   105.000000    19.374705     0.135069
# std     498.974949       0.039274    12.250994    24.603949     0.111972
# min       0.000000       0.057000    90.000000     0.000000     0.020659
# 25%     431.750000       0.057000    90.000000     0.000000     0.051642
# 50%     863.500000       0.100000   105.000000     8.050000     0.098352
# 75%    1295.250000       0.153000   120.000000    29.877500     0.155256
# max    1727.000000       0.153000   120.000000   100.000000     0.483155

# %%
# 分析参数列和目标列
parameter_columns = ['base', 'ligand', 'solvent', 'concentration', 'temperature']
objective_columns = ['yield', 'cost']

print("🔍 参数列分析:")
for col in parameter_columns:
    unique_values = df[col].unique()
    print(f"  {col}: {len(unique_values)}个唯一值")
    if len(unique_values) <= 12:
        print(f"    值: {list(unique_values)}")
    else:
        print(f"    值范围: {min(unique_values)} - {max(unique_values)}")

print("\n🎯 目标列分析:")
for col in objective_columns:
    print(f"  {col}: 范围 {df[col].min():.3f} - {df[col].max():.3f}, 均值 {df[col].mean():.3f}")
# Out:
# 🔍 参数列分析:
#   base: 4个唯一值
#     值: ['KOAc', 'KOPiv', 'CsOAc', 'CsOPiv']
#   ligand: 12个唯一值
#     值: ['BrettPhos', 'PPhtBu2', 'tBPh-CPhos', 'PCy3 HBF4', 'PPh3', 'X-Phos', 'P(fur)3', 'PPh2Me', 'GorlosPhos HBF4', 'JackiePhos', 'CgMe-PPh', 'PPhMe2']
#   solvent: 4个唯一值
#     值: ['DMAc', 'BuCN', 'BuOAc', 'p-Xylene']
#   concentration: 3个唯一值
#     值: [np.float64(0.1), np.float64(0.057), np.float64(0.153)]
#   temperature: 3个唯一值
#     值: [np.int64(105), np.int64(90), np.int64(120)]
#
# 🎯 目标列分析:
#   yield: 范围 0.000 - 100.000, 均值 19.375
#   cost: 范围 0.021 - 0.483, 均值 0.135

# %%
import json
import numpy as np

def build_parameter_space(df, parameter_columns):
    """根据数据构建参数空间 - 所有参数都是choice类型"""
    parameter_space = []
    
    for col in parameter_columns:
        unique_values = df[col].unique()
        
        # 转换成原生 Python 类型，避免 np.int64 / np.float64 报错
        converted_values = [v.item() if isinstance(v, (np.generic,)) else v for v in unique_values]
        
        parameter_space.append({
            "name": col,
            "type": "choice",
            "values": converted_values
        })
    
    return parameter_space

# 构建参数空间
parameter_space = build_parameter_space(df, parameter_columns)
print("🔧 构建的参数空间:")
for param in parameter_space:
    print(f"  {param['name']}: {param['type']} - {param['values']}")

print(f"\n📋 参数空间JSON格式:")
print(json.dumps(parameter_space, indent=2, ensure_ascii=False))
# Out:
# 🔧 构建的参数空间:
#   base: choice - ['KOAc', 'KOPiv', 'CsOAc', 'CsOPiv']
#   ligand: choice - ['BrettPhos', 'PPhtBu2', 'tBPh-CPhos', 'PCy3 HBF4', 'PPh3', 'X-Phos', 'P(fur)3', 'PPh2Me', 'GorlosPhos HBF4', 'JackiePhos', 'CgMe-PPh', 'PPhMe2']
#   solvent: choice - ['DMAc', 'BuCN', 'BuOAc', 'p-Xylene']
#   concentration: choice - [0.1, 0.057, 0.153]
#   temperature: choice - [105, 90, 120]
#
# 📋 参数空间JSON格式:
# [
#   {
#     "name": "base",
#     "type": "choice",
#     "values": [
#       "KOAc",
#       "KOPiv",
#       "CsOAc",
#       "CsOPiv"
#     ]
#   },
#   {
#     "name": "ligand",
#     "type": "choice",
#     "values": [
#       "BrettPhos",
#       "PPhtBu2",
#       "tBPh-CPhos",
#       "PCy3 HBF4",
#       "PPh3",
#       "X-Phos",
#       "P(fur)3",
#       "PPh2Me",
#       "GorlosPhos HBF4",
#       "JackiePhos",
#       "CgMe-PPh",
#       "PPhMe2"
#     ]
#   },
#   {
#     "name": "solvent",
#     "type": "choice",
#     "values": [
#       "DMAc",
#       "BuCN",
#       "BuOAc",
#       "p-Xylene"
#     ]
#   },
#   {
#     "name": "concentration",
#     "type": "choice",
#     "values": [
#       0.1,
#       0.057,
#       0.153
#     ]
#   },
#   {
#     "name": "temperature",
#     "type": "choice",
#     "values": [
#       105,
#       90,
#       120
#     ]
#   }
# ]

# %%
# 定义优化目标
objectives = {
    "yield": {"minimize": False},  # 最大化yield
    "cost": {"minimize": True}    # 最小化成本
}

print("🎯 优化目标:")
for obj, config in objectives.items():
    direction = "最小化" if config["minimize"] else "最大化"
    print(f"  {obj}: {direction}")

# 目标权重（可选）
objective_weights = {
    "yield": 0.7,  # 产率权重70%
    "cost": 0.3    # 成本权重30%
}

print(f"\n⚖️ 目标权重: {objective_weights}")

# 保存配置供后续使用
config = {
    'parameter_space': parameter_space,
    'objectives': objectives,
    'objective_weights': objective_weights,
    'parameter_columns': parameter_columns,
    'objective_columns': objective_columns
}

print("\n✅ 配置已保存，可以进入下一步测试API接口")
# Out:
# 🎯 优化目标:
#   yield: 最大化
#   cost: 最小化
#
# ⚖️ 目标权重: {'yield': 0.7, 'cost': 0.3}
#
# ✅ 配置已保存，可以进入下一步测试API接口

# %%
import requests
import time

# API配置
API_BASE_URL = "http://localhost:3320"
INIT_ENDPOINT = f"{API_BASE_URL}/init"
UPDATE_ENDPOINT = f"{API_BASE_URL}/update"

print("🔧 API配置:")
print(f"   基础URL: {API_BASE_URL}")
print(f"   Init接口: {INIT_ENDPOINT}")
print(f"   Update接口: {UPDATE_ENDPOINT}")

# 测试API连接
def test_api_connection():
    """测试API连接"""
    try:
        response = requests.get(f"{API_BASE_URL}/docs")
        if response.status_code == 200:
            print("✅ API服务器连接正常")
            return True
        else:
            print(f"❌ API服务器响应异常: {response.status_code}")
            return False
    except Exception as e:
        print(f"❌ API连接失败: {str(e)}")
        return False

# 测试连接
api_connected = test_api_connection()
if not api_connected:
    print("⚠️ 请确保API服务器正在运行: python api_parameter_optimizer_v3.py")
# Out:
# 🔧 API配置:
#    基础URL: http://localhost:3320
#    Init接口: http://localhost:3320/init
#    Update接口: http://localhost:3320/update
# ✅ API服务器连接正常

# %%
def call_init_api(parameter_space, objectives, batch_size=5, seed=None):
    """调用init接口初始化优化器"""
    
    # 构建请求数据
    init_request = {
        "parameter_space": parameter_space,
        "objectives": list(objectives.keys()),
        "batch": batch_size,
        "seed": seed,
        "sampling_method": "lhs"  # 使用sobol采样
    }
    
    print(f"🚀 调用init接口，批次大小: {batch_size}")
    print(f"�� 请求数据: {json.dumps(init_request, indent=2, ensure_ascii=False)}")
    
    try:
        response = requests.post(INIT_ENDPOINT, json=init_request)
        
        if response.status_code == 200:
            result = response.json()
            print(f"✅ Init接口调用成功")
            print(f"�� 采样方法: {result['sampling_method']}")
            print(f"📈 生成参数组合数: {len(result['results'])}")
            print(f"💬 消息: {result['message']}")
            return result
        else:
            print(f"❌ Init接口调用失败: {response.status_code}")
            print(f"📄 错误信息: {response.text}")
            return None
            
    except Exception as e:
        print(f"❌ Init接口调用异常: {str(e)}")
        return None

# 调用init接口
init_result = call_init_api(parameter_space, objectives, batch_size=5)

if init_result:
    print("\n�� 生成的参数组合:")
    for i, params in enumerate(init_result['results'], 1):
        print(f"  {i}. {params}")
# Out:
# 🚀 调用init接口，批次大小: 5
# �� 请求数据: {
#   "parameter_space": [
#     {
#       "name": "base",
#       "type": "choice",
#       "values": [
#         "KOAc",
#         "KOPiv",
#         "CsOAc",
#         "CsOPiv"
#       ]
#     },
#     {
#       "name": "ligand",
#       "type": "choice",
#       "values": [
#         "BrettPhos",
#         "PPhtBu2",
#         "tBPh-CPhos",
#         "PCy3 HBF4",
#         "PPh3",
#         "X-Phos",
#         "P(fur)3",
#         "PPh2Me",
#         "GorlosPhos HBF4",
#         "JackiePhos",
#         "CgMe-PPh",
#         "PPhMe2"
#       ]
#     },
#     {
#       "name": "solvent",
#       "type": "choice",
#       "values": [
#         "DMAc",
#         "BuCN",
#         "BuOAc",
#         "p-Xylene"
#       ]
#     },
#     {
#       "name": "concentration",
#       "type": "choice",
#       "values": [
#         0.1,
#         0.057,
#         0.153
#       ]
#     },
#     {
#       "name": "temperature",
#       "type": "choice",
#       "values": [
#         105,
#         90,
#         120
#       ]
#     }
#   ],
#   "objectives": [
#     "yield",
#     "cost"
#   ],
#   "batch": 5,
#   "seed": null,
#   "sampling_method": "lhs"
# }
# ✅ Init接口调用成功
# �� 采样方法: lhs
# 📈 生成参数组合数: 5
# 💬 消息: 初始化成功，使用lhs采样生成5个参数组合
#
# �� 生成的参数组合:
#   1. {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 105}
#   2. {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105}
#   3. {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120}
#   4. {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120}
#   5. {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90}

# %%
def simulate_experiment_results(params_list, df, random_seed=None):
    """从真实数据中查找完全匹配的实验结果"""
    # 设置随机种子确保结果一致性
    np.random.seed(random_seed)
    
    results = []
    
    for params in params_list:
        # 构建精确匹配的查询条件
        query_conditions = []
        for key, value in params.items():
            # 所有参数都进行精确匹配
            if isinstance(value, str):
                query_conditions.append(f"{key} == '{value}'")
            else:
                query_conditions.append(f"{key} == {value}")
        
        # 构建查询字符串
        query_str = " and ".join(query_conditions)
        
        try:
            # 查找完全匹配的数据
            matched_data = df.query(query_str)
            
            if len(matched_data) > 0:
                # 取第一个匹配的结果
                row = matched_data.iloc[0]
                experiment_result = {
                    "parameters": params,
                    "metrics": {
                        "yield": float(row['yield']),
                        "cost": float(row['cost'])
                        
                    }
                }
                results.append(experiment_result)
                print(f"✅ 找到完全匹配: {params} -> yield={row['yield']:.2f}, cost={row['cost']:.3f}")
            else:
                # 没有找到完全匹配，尝试查找最接近的参数组合
                print(f"⚠️ 未找到完全匹配: {params}")
                print(f"   尝试查找最接近的参数组合...")
                
                # 计算每个参数的距离
                best_match = None
                min_distance = float('inf')
                
                for _, row in df.iterrows():
                    distance = 0
                    match = True
                    
                    for key, target_value in params.items():
                        actual_value = row[key]
                        
                        if key in ['base', 'ligand', 'solvent']:
                            # 类别参数必须完全匹配
                            if actual_value != target_value:
                                match = False
                                break
                        else:
                            # 数值参数计算距离
                            distance += abs(actual_value - target_value)
                    
                    if match and distance < min_distance:
                        min_distance = distance
                        best_match = row
                
                if best_match is not None:
                    experiment_result = {
                        "parameters": params,
                        "metrics": {
                            "yield": float(best_match['yield']),
                            "cost": float(best_match['cost'])
                        }
                    }
                    results.append(experiment_result)
                    print(f"✅ 找到最接近匹配: {params} -> yield={best_match['yield']:.2f}, cost={best_match['cost']:.3f}")
                else:
                    print(f"❌ 未找到任何匹配: {params}")
                    # 如果实在找不到，使用随机结果（这种情况应该很少）
                    random_row = df.sample(1, random_state=random_seed).iloc[0]
                    experiment_result = {
                        "parameters": params,
                        "metrics": {
                            "yield": float(random_row['yield']),
                            "cost": float(random_row['cost'])
                        }
                    }
                    results.append(experiment_result)
                    print(f"⚠️ 使用随机结果: {params} -> yield={random_row['yield']:.2f}, cost={random_row['cost']:.3f}")
                
        except Exception as e:
            print(f"❌ 查询失败: {str(e)}")
            # 使用随机结果
            random_row = df.sample(1, random_state=random_seed).iloc[0]
            experiment_result = {
                "parameters": params,
                "metrics": {
                    "yield": float(random_row['yield']),
                    "cost": float(random_row['cost'])
                }
            }
            results.append(experiment_result)
    
    return results

# 模拟第一轮实验结果
if 'init_result' in locals() and init_result:
    print("\n🧪 模拟第一轮实验结果:")
    first_round_results = simulate_experiment_results(init_result['results'], df)
    
    print("\n�� 第一轮实验结果:")
    for i, result in enumerate(first_round_results, 1):
        params = result['parameters']
        metrics = result['metrics']
        print(f"  {i}. 参数: {params}")
        print(f"     结果: yield={metrics['yield']:.2f}, cost={metrics['cost']:.3f}")
# Out:
# 🧪 模拟第一轮实验结果:
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 105} -> yield=4.28, cost=0.043
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=0.00, cost=0.077
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=75.12, cost=0.356
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=54.52, cost=0.094
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=0.00, cost=0.242
#
# �� 第一轮实验结果:
#   1. 参数: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 105}
#      结果: yield=4.28, cost=0.043
#   2. 参数: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105}
#      结果: yield=0.00, cost=0.077
#   3. 参数: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120}
#      结果: yield=75.12, cost=0.356
#   4. 参数: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120}
#      结果: yield=54.52, cost=0.094
#   5. 参数: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90}
#      结果: yield=0.00, cost=0.242

# %%
def call_update_api(parameter_space, objectives, completed_experiments, batch_size=3, use_weights=False, seed=None):
    """调用update接口进行贝叶斯优化"""
    
    # 构建请求数据
    update_request = {
        "parameter_space": parameter_space,
        "objectives": objectives,
        "completed_experiments": completed_experiments,
        "batch": batch_size,
        "use_weights": use_weights,
        "objective_weights": objective_weights if use_weights else None,
        "additional_metrics": ["yield", "cost"],
        "seed": seed    
    }
    
    print(f"�� 调用update接口，批次大小: {batch_size}")
    print(f"📊 已完成实验数: {len(completed_experiments)}")
    print(f"⚖️ 使用权重: {use_weights}")
    
    try:
        response = requests.post(UPDATE_ENDPOINT, json=update_request)
        
        if response.status_code == 200:
            result = response.json()
            print(f"✅ Update接口调用成功")
            print(f"📈 推荐参数组合数: {len(result['results'])}")
            print(f"💬 消息: {result['message']}")
            return result
        else:
            print(f"❌ Update接口调用失败: {response.status_code}")
            print(f"📄 错误信息: {response.text}")
            return None
            
    except Exception as e:
        print(f"❌ Update接口调用异常: {str(e)}")
        return None

# 调用update接口
if 'first_round_results' in locals():
    update_result = call_update_api(parameter_space, objectives, first_round_results, batch_size=3)
    
    if update_result:
        print("\n🔍 推荐的下一轮参数组合:")
        for i, params in enumerate(update_result['results'], 1):
            print(f"  {i}. {params}")
# Out:
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 5
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
#
# 🔍 推荐的下一轮参数组合:
#   1. {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120}
#   2. {'base': 'CsOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120}
#   3. {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120}

# %%
def run_optimization_loop(parameter_space, objectives, df, n_rounds=15, init_batch=20, update_batch=3, seed=None  ):
    """运行多轮优化循环"""
    
    all_experiments = []
    optimization_history = []
    
    print(f"🔄 开始{n_rounds}轮优化循环")
    print(f"📊 初始批次: {init_batch}, 更新批次: {update_batch}")
    
    # 第一轮：初始化
    print("\n=== 第1轮：初始化 ===")
    init_result = call_init_api(parameter_space, objectives, batch_size=init_batch,seed=seed)
    
    if not init_result:
        print("❌ 初始化失败，退出优化循环")
        return None, None
    
    # 模拟第一轮实验结果
    round_results = simulate_experiment_results(init_result['results'], df)
    all_experiments.extend(round_results)
    
    # 记录历史
    optimization_history.append({
        'round': 1,
        'type': 'init',
        'parameters': init_result['results'],
        'results': round_results,
        'best_yield': max([r['metrics']['yield'] for r in round_results]),
        'best_cost': min([r['metrics']['cost'] for r in round_results])
    })
    
    print(f"📈 第1轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
    
    # 后续轮次：贝叶斯优化
    for round_num in range(2, n_rounds + 1):
        print(f"\n=== 第{round_num}轮：贝叶斯优化 ===")
        
        # 调用update接口
        update_result = call_update_api(parameter_space, objectives, all_experiments, batch_size=update_batch, seed=seed)
        
        if not update_result:
            print(f"❌ 第{round_num}轮更新失败，退出优化循环")
            break
        
        # 模拟实验结果
        round_results = simulate_experiment_results(update_result['results'], df)
        all_experiments.extend(round_results)
        
        # 记录历史
        optimization_history.append({
            'round': round_num,
            'type': 'update',
            'parameters': update_result['results'],
            'results': round_results,
            'best_yield': max([r['metrics']['yield'] for r in round_results]),
            'best_cost': min([r['metrics']['cost'] for r in round_results])
        })
        
        print(f"�� 第{round_num}轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
        
        # 添加延迟，避免请求过快
        # time.sleep(1)
    
    return all_experiments, optimization_history

# 运行优化循环
all_experiments, optimization_history = run_optimization_loop(parameter_space, objectives, df)
# Out:
# 🔄 开始15轮优化循环
# 📊 初始批次: 20, 更新批次: 3
#
# === 第1轮：初始化 ===
# 🚀 调用init接口，批次大小: 20
# �� 请求数据: {
#   "parameter_space": [
#     {
#       "name": "base",
#       "type": "choice",
#       "values": [
#         "KOAc",
#         "KOPiv",
#         "CsOAc",
#         "CsOPiv"
#       ]
#     },
#     {
#       "name": "ligand",
#       "type": "choice",
#       "values": [
#         "BrettPhos",
#         "PPhtBu2",
#         "tBPh-CPhos",
#         "PCy3 HBF4",
#         "PPh3",
#         "X-Phos",
#         "P(fur)3",
#         "PPh2Me",
#         "GorlosPhos HBF4",
#         "JackiePhos",
#         "CgMe-PPh",
#         "PPhMe2"
#       ]
#     },
#     {
#       "name": "solvent",
#       "type": "choice",
#       "values": [
#         "DMAc",
#         "BuCN",
#         "BuOAc",
#         "p-Xylene"
#       ]
#     },
#     {
#       "name": "concentration",
#       "type": "choice",
#       "values": [
#         0.1,
#         0.057,
#         0.153
#       ]
#     },
#     {
#       "name": "temperature",
#       "type": "choice",
#       "values": [
#         105,
#         90,
#         120
#       ]
#     }
#   ],
#   "objectives": [
#     "yield",
#     "cost"
#   ],
#   "batch": 20,
#   "seed": null,
#   "sampling_method": "lhs"
# }
# ✅ Init接口调用成功
# �� 采样方法: lhs
# 📈 生成参数组合数: 20
# 💬 消息: 初始化成功，使用lhs采样生成20个参数组合
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhMe2', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=0.00, cost=0.028
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105} -> yield=20.63, cost=0.137
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhtBu2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.100
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=48.91, cost=0.037
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPh2Me', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105} -> yield=0.53, cost=0.154
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=12.23, cost=0.278
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=6.77, cost=0.398
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'P(fur)3', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90} -> yield=2.55, cost=0.056
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=8.69, cost=0.160
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=55.96, cost=0.120
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'GorlosPhos HBF4', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=40.26, cost=0.079
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=21.86, cost=0.364
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PCy3 HBF4', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=0.55, cost=0.080
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=32.36, cost=0.072
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90} -> yield=2.58, cost=0.028
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120} -> yield=12.19, cost=0.066
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=11.91, cost=0.158
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90} -> yield=17.92, cost=0.148
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPhtBu2', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120} -> yield=0.00, cost=0.170
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.032
# 📈 第1轮最佳结果: yield=55.96, cost=0.028
#
# === 第2轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 20
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.034
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 90} -> yield=0.00, cost=0.130
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPhtBu2', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.125
# �� 第2轮最佳结果: yield=0.00, cost=0.034
#
# === 第3轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 23
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'P(fur)3', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=27.05, cost=0.128
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=80.61, cost=0.034
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'GorlosPhos HBF4', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=40.61, cost=0.102
# �� 第3轮最佳结果: yield=80.61, cost=0.034
#
# === 第4轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 26
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 105} -> yield=41.90, cost=0.039
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=82.09, cost=0.269
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 105} -> yield=49.40, cost=0.125
# �� 第4轮最佳结果: yield=82.09, cost=0.039
#
# === 第5轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 29
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=68.33, cost=0.268
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=45.01, cost=0.263
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=8.61, cost=0.266
# �� 第5轮最佳结果: yield=68.33, cost=0.263
#
# === 第6轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 32
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=77.58, cost=0.045
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=64.46, cost=0.033
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=88.41, cost=0.035
# �� 第6轮最佳结果: yield=88.41, cost=0.033
#
# === 第7轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 35
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPh3', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=0.78, cost=0.023
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhMe2', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=3.33, cost=0.039
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=5.90, cost=0.084
# �� 第7轮最佳结果: yield=5.90, cost=0.023
#
# === 第8轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 38
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=84.81, cost=0.080
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=84.67, cost=0.030
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=28.36, cost=0.032
# �� 第8轮最佳结果: yield=84.81, cost=0.030
#
# === 第9轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 41
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'P(fur)3', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=9.88, cost=0.052
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'P(fur)3', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 90} -> yield=15.86, cost=0.052
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 120} -> yield=12.34, cost=0.034
# �� 第9轮最佳结果: yield=15.86, cost=0.034
#
# === 第10轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 44
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'P(fur)3', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105} -> yield=11.69, cost=0.036
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.023
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhMe2', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 90} -> yield=0.00, cost=0.035
# �� 第10轮最佳结果: yield=11.69, cost=0.023
#
# === 第11轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 47
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=0.00, cost=0.028
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.034
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=5.02, cost=0.036
# �� 第11轮最佳结果: yield=5.02, cost=0.028
#
# === 第12轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 50
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=48.34, cost=0.116
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 90} -> yield=0.00, cost=0.045
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=6.26, cost=0.187
# �� 第12轮最佳结果: yield=48.34, cost=0.045
#
# === 第13轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 53
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhtBu2', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.037
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=62.60, cost=0.315
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=28.53, cost=0.108
# �� 第13轮最佳结果: yield=62.60, cost=0.037
#
# === 第14轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 56
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhMe2', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=0.00, cost=0.024
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhtBu2', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=0.00, cost=0.052
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=99.81, cost=0.052
# �� 第14轮最佳结果: yield=99.81, cost=0.024
#
# === 第15轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 59
# ⚖️ 使用权重: False

# %%
# 将优化历史结果保存到CSV文件
def save_optimization_history_to_csv(optimization_history, filename="optimization_results.csv"):
    """将优化历史结果保存到CSV文件"""
    
    if not optimization_history:
        print("❌ 没有优化历史数据可保存")
        return
    
    # 准备数据
    csv_data = []
    
    for round_data in optimization_history:
        round_num = round_data['round']
        round_type = round_data['type']
        best_yield = round_data['best_yield']
        best_cost = round_data['best_cost']
        
        # 为每个参数组合创建一行
        for i, (params, result) in enumerate(zip(round_data['parameters'], round_data['results'])):
            row = {
                'round': round_num,
                'type': round_type,
                'experiment_id': f"R{round_num}_E{i+1}",
                'base': params['base'],
                'ligand': params['ligand'],
                'solvent': params['solvent'],
                'concentration': params['concentration'],
                'temperature': params['temperature'],
                'yield': result['metrics']['yield'],
                'cost': result['metrics']['cost'],
                'best_yield_in_round': best_yield,
                'best_cost_in_round': best_cost
                    
            }
            csv_data.append(row)
    
    # 创建DataFrame并保存
    df_results = pd.DataFrame(csv_data)
    
    # 保存到CSV
    df_results.to_csv(filename, index=False, encoding='utf-8')
    
    print(f"✅ 优化结果已保存到: {filename}")
    print(f"📊 共保存 {len(df_results)} 个实验结果")
    print(f"🔄 包含 {len(optimization_history)} 轮优化")
    
    # 显示数据预览
    print("\n📋 数据预览:")
    print(df_results.head())
    
    # 显示统计信息
    print("\n📈 统计信息:")
    print(f"  总实验数: {len(df_results)}")
    print(f"  总轮次: {df_results['round'].nunique()}")
    print(f"  最佳产率: {df_results['yield'].max():.2f}")
    print(f"  最佳成本: {df_results['cost'].min():.3f}")
    print(f"  平均产率: {df_results['yield'].mean():.2f}")
    print(f"  平均成本: {df_results['cost'].mean():.3f}")
    
    return df_results

# 保存优化结果
if 'optimization_history' in locals() and optimization_history:
    print("💾 保存优化历史结果到CSV文件...")
    results_df = save_optimization_history_to_csv(optimization_history, "bayesian_optimization_results.csv")
    
    # 额外保存汇总数据
    summary_data = []
    for round_data in optimization_history:
        summary_row = {
            'round': round_data['round'],
            'type': round_data['type'],
            'experiments_count': len(round_data['parameters']),
            'best_yield': round_data['best_yield'],
            'best_cost': round_data['best_cost'],
            'avg_yield': np.mean([r['metrics']['yield'] for r in round_data['results']]),
            'avg_cost': np.mean([r['metrics']['cost'] for r in round_data['results']])
        }
        summary_data.append(summary_row)
    
    summary_df = pd.DataFrame(summary_data)
    summary_df.to_csv("optimization_summary.csv", index=False, encoding='utf-8')
    print("✅ 优化汇总数据已保存到: optimization_summary.csv")
    
    print("\n�� 生成的文件:")
    print("  - bayesian_optimization_results.csv: 详细实验结果")
    print("  - optimization_summary.csv: 轮次汇总数据")
    
else:
    print("❌ 没有找到optimization_history数据，请先运行优化循环")
# Out:
# 💾 保存优化历史结果到CSV文件...
# ✅ 优化结果已保存到: bayesian_optimization_results.csv
# 📊 共保存 62 个实验结果
# 🔄 包含 15 轮优化
#
# 📋 数据预览:
#    round  type experiment_id    base      ligand   solvent  concentration  \
# 0      1  init         R1_E1   KOPiv  tBPh-CPhos  p-Xylene          0.057
# 1      1  init         R1_E2   CsOAc   PCy3 HBF4     BuOAc          0.153
# 2      1  init         R1_E3  CsOPiv      PPh2Me      DMAc          0.100
# 3      1  init         R1_E4    KOAc   BrettPhos      BuCN          0.153
# 4      1  init         R1_E5    KOAc      PPhMe2     BuOAc          0.100
#
#    temperature  yield      cost  best_yield_in_round  best_cost_in_round
# 0          105  21.43  0.281991                84.67            0.022862
# 1          120   0.00  0.080855                84.67            0.022862
# 2          120   3.70  0.113735                84.67            0.022862
# 3           90  12.07  0.153179                84.67            0.022862
# 4           90   0.00  0.040323                84.67            0.022862
#
# 📈 统计信息:
#   总实验数: 62
#   总轮次: 15
#   最佳产率: 91.27
#   最佳成本: 0.021
#   平均产率: 36.89
#   平均成本: 0.089
# ✅ 优化汇总数据已保存到: optimization_summary.csv
#
# �� 生成的文件:
#   - bayesian_optimization_results.csv: 详细实验结果
#   - optimization_summary.csv: 轮次汇总数据

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
results_df
# Out:
#     round    type experiment_id    base           ligand   solvent  \
# 0       1    init         R1_E1   KOPiv       tBPh-CPhos  p-Xylene
# 1       1    init         R1_E2   CsOAc        PCy3 HBF4     BuOAc
# 2       1    init         R1_E3  CsOPiv           PPh2Me      DMAc
# 3       1    init         R1_E4    KOAc        BrettPhos      BuCN
# 4       1    init         R1_E5    KOAc           PPhMe2     BuOAc
# 5       1    init         R1_E6  CsOPiv  GorlosPhos HBF4  p-Xylene
# 6       1    init         R1_E7   CsOAc          PPhtBu2      BuCN
# 7       1    init         R1_E8   KOPiv          P(fur)3      DMAc
# 8       1    init         R1_E9   KOPiv             PPh3      BuCN
# 9       1    init        R1_E10   CsOAc        BrettPhos      DMAc
# 10      1    init        R1_E11  CsOPiv       tBPh-CPhos     BuOAc
# 11      1    init        R1_E12    KOAc        PCy3 HBF4  p-Xylene
# 12      1    init        R1_E13    KOAc           X-Phos      DMAc
# 13      1    init        R1_E14  CsOPiv       JackiePhos      BuCN
# 14      1    init        R1_E15   CsOAc           PPhMe2  p-Xylene
# 15      1    init        R1_E16   KOPiv  GorlosPhos HBF4     BuOAc
# 16      1    init        R1_E17   KOPiv           PPhMe2      DMAc
# 17      1    init        R1_E18   CsOAc         CgMe-PPh      BuCN
# 18      1    init        R1_E19  CsOPiv           X-Phos  p-Xylene
# 19      1    init        R1_E20    KOAc       JackiePhos     BuOAc
# 20      2  update         R2_E1    KOAc        PCy3 HBF4      DMAc
# 21      2  update         R2_E2   CsOAc           X-Phos  p-Xylene
# 22      2  update         R2_E3   KOPiv           X-Phos      DMAc
# 23      3  update         R3_E1   KOPiv           X-Phos      BuCN
# 24      3  update         R3_E2   KOPiv           X-Phos  p-Xylene
# 25      3  update         R3_E3    KOAc        BrettPhos      BuCN
# 26      4  update         R4_E1   KOPiv         CgMe-PPh      BuCN
# 27      4  update         R4_E2   KOPiv           X-Phos     BuOAc
# 28      4  update         R4_E3   KOPiv         CgMe-PPh      BuCN
# 29      5  update         R5_E1   KOPiv         CgMe-PPh     BuOAc
# 30      5  update         R5_E2   CsOAc         CgMe-PPh      BuCN
# 31      5  update         R5_E3    KOAc           X-Phos  p-Xylene
# 32      6  update         R6_E1   KOPiv          P(fur)3      BuCN
# 33      6  update         R6_E2   KOPiv           X-Phos      DMAc
# 34      6  update         R6_E3  CsOPiv           X-Phos     BuOAc
# 35      7  update         R7_E1    KOAc           X-Phos      DMAc
# 36      7  update         R7_E2   KOPiv           X-Phos  p-Xylene
# 37      7  update         R7_E3  CsOPiv           X-Phos      BuCN
# 38      8  update         R8_E1   KOPiv           X-Phos      DMAc
# 39      8  update         R8_E2  CsOPiv         CgMe-PPh  p-Xylene
# 40      8  update         R8_E3    KOAc           X-Phos      DMAc
# 41      9  update         R9_E1   KOPiv         CgMe-PPh      BuCN
# 42      9  update         R9_E2   KOPiv          P(fur)3  p-Xylene
# 43      9  update         R9_E3   KOPiv         CgMe-PPh  p-Xylene
# 44     10  update        R10_E1    KOAc       tBPh-CPhos      DMAc
# 45     10  update        R10_E2   CsOAc         CgMe-PPh  p-Xylene
# 46     10  update        R10_E3   KOPiv           PPh2Me      DMAc
# 47     11  update        R11_E1    KOAc             PPh3     BuOAc
# 48     11  update        R11_E2    KOAc           X-Phos     BuOAc
# 49     11  update        R11_E3    KOAc          P(fur)3  p-Xylene
# 50     12  update        R12_E1    KOAc         CgMe-PPh     BuOAc
# 51     12  update        R12_E2   KOPiv           X-Phos      DMAc
# 52     12  update        R12_E3    KOAc  GorlosPhos HBF4  p-Xylene
# 53     13  update        R13_E1    KOAc           PPh2Me  p-Xylene
# 54     13  update        R13_E2    KOAc           X-Phos     BuOAc
# 55     13  update        R13_E3   KOPiv             PPh3      DMAc
# 56     14  update        R14_E1    KOAc           X-Phos      DMAc
# 57     14  update        R14_E2   KOPiv             PPh3  p-Xylene
# 58     14  update        R14_E3   CsOAc           X-Phos      DMAc
# 59     15  update        R15_E1   KOPiv             PPh3     BuOAc
# 60     15  update        R15_E2   KOPiv           PPhMe2      DMAc
# 61     15  update        R15_E3   KOPiv             PPh3      DMAc
#
#     concentration  temperature  yield      cost  best_yield_in_round  \
# 0           0.057          105  21.43  0.281991                84.67
# 1           0.153          120   0.00  0.080855                84.67
# 2           0.100          120   3.70  0.113735                84.67
# 3           0.153           90  12.07  0.153179                84.67
# 4           0.100           90   0.00  0.040323                84.67
# 5           0.100          120   9.03  0.127139                84.67
# 6           0.153          105   0.00  0.096028                84.67
# 7           0.057           90  26.56  0.047702                84.67
# 8           0.100          105   4.28  0.043053                84.67
# 9           0.100          105   4.74  0.191274                84.67
# 10          0.057           90  16.51  0.385653                84.67
# 11          0.153          120   0.00  0.029082                84.67
# 12          0.153          120  84.67  0.030083                84.67
# 13          0.057           90  11.65  0.483155                84.67
# 14          0.100           90   0.00  0.076433                84.67
# 15          0.057          105  10.68  0.067646                84.67
# 16          0.153           90   0.00  0.022862                84.67
# 17          0.057          120  50.74  0.144334                84.67
# 18          0.100          120  55.80  0.123393                84.67
# 19          0.100          105   7.74  0.367772                84.67
# 20          0.057           90   3.40  0.042297                80.39
# 21          0.153          120  70.80  0.077171                80.39
# 22          0.153          120  80.39  0.028976                80.39
# 23          0.153          120  71.43  0.041269                71.43
# 24          0.153          120  62.15  0.030544                71.43
# 25          0.057          120  17.00  0.186570                71.43
# 26          0.153          105  69.20  0.064527                76.68
# 27          0.100           90  42.30  0.045349                76.68
# 28          0.100          105  76.68  0.075080                76.68
# 29          0.100          120  42.62  0.068626                61.67
# 30          0.100           90  57.95  0.121531                61.67
# 31          0.153          120  61.67  0.031637                61.67
# 32          0.153          105  57.68  0.045267                62.07
# 33          0.057          120  62.07  0.043701                62.07
# 34          0.153          105   5.53  0.124089                62.07
# 35          0.153           90  38.79  0.029950                78.44
# 36          0.057           90  23.45  0.047575                78.44
# 37          0.153          120  78.44  0.128791                78.44
# 38          0.153           90  60.68  0.028919                77.58
# 39          0.057          105  11.91  0.158276                77.58
# 40          0.057          120  77.58  0.044840                77.58
# 41          0.153           90  52.23  0.064397                52.23
# 42          0.153           90  37.30  0.034556                52.23
# 43          0.153          120  44.47  0.053754                52.23
# 44          0.057           90  57.27  0.279205                91.19
# 45          0.153          120  91.19  0.100520                91.19
# 46          0.153           90   2.29  0.021612                91.19
# 47          0.153           90   1.39  0.029495                73.71
# 48          0.100          120  73.71  0.046620                73.71
# 49          0.153           90  10.66  0.035554                73.71
# 50          0.057           90  12.61  0.088109                80.61
# 51          0.100          120  80.61  0.033627                80.61
# 52          0.100           90   0.70  0.040735                80.61
# 53          0.100           90   0.00  0.029677                79.10
# 54          0.153          120  76.24  0.038113                79.10
# 55          0.153          120  79.10  0.020775                79.10
# 56          0.100          120  88.41  0.034744                88.41
# 57          0.153          120   7.54  0.022148                88.41
# 58          0.100          120  84.81  0.080234                88.41
# 59          0.153          120   4.33  0.028417                91.27
# 60          0.153          120   0.00  0.022862                91.27
# 61          0.057          120  91.27  0.035588                91.27
#
#     best_cost_in_round
# 0             0.022862
# 1             0.022862
# 2             0.022862
# 3             0.022862
# 4             0.022862
# 5             0.022862
# 6             0.022862
# 7             0.022862
# 8             0.022862
# 9             0.022862
# 10            0.022862
# 11            0.022862
# 12            0.022862
# 13            0.022862
# 14            0.022862
# 15            0.022862
# 16            0.022862
# 17            0.022862
# 18            0.022862
# 19            0.022862
# 20            0.028976
# 21            0.028976
# 22            0.028976
# 23            0.030544
# 24            0.030544
# 25            0.030544
# 26            0.045349
# 27            0.045349
# 28            0.045349
# 29            0.031637
# 30            0.031637
# 31            0.031637
# 32            0.043701
# 33            0.043701
# 34            0.043701
# 35            0.029950
# 36            0.029950
# 37            0.029950
# 38            0.028919
# 39            0.028919
# 40            0.028919
# 41            0.034556
# 42            0.034556
# 43            0.034556
# 44            0.021612
# 45            0.021612
# 46            0.021612
# 47            0.029495
# 48            0.029495
# 49            0.029495
# 50            0.033627
# 51            0.033627
# 52            0.033627
# 53            0.020775
# 54            0.020775
# 55            0.020775
# 56            0.022148
# 57            0.022148
# 58            0.022148
# 59            0.022862
# 60            0.022862
# 61            0.022862
