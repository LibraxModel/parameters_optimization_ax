# %%
import pandas as pd
import numpy as np
import json
from typing import List, Dict, Any

print("✅ 库导入完成")

# 读取实验数据
data_file = "point_hypervolume.csv"
df = pd.read_csv(data_file)

print(f"�� 数据加载完成，共{len(df)}行数据")
print(f"📋 列名: {list(df.columns)}")
print("\n🔍 数据预览:")
print(df.head())
print("\n📈 数据统计:")
print(df.describe())
# Out:
# ✅ 库导入完成
# �� 数据加载完成，共1728行数据
# 📋 列名: ['new_index', 'base', 'ligand', 'solvent', 'concentration', 'temperature', 'yield', 'cost', 'point_hypervolume']
#
# 🔍 数据预览:
#    new_index   base    ligand solvent  concentration  temperature  yield  \
# 0       1642  KOPiv  CgMe-PPh    DMAc          0.153          120  99.81
# 1       1546  KOPiv  CgMe-PPh    DMAc          0.153          105  98.49
# 2       1636   KOAc  CgMe-PPh    DMAc          0.153          120  98.38
# 3        490  KOPiv      PPh3    DMAc          0.057          120  91.27
# 4       1348   KOAc  CgMe-PPh    DMAc          0.057          120  96.64
#
#        cost  point_hypervolume
# 0  0.052307           0.929802
# 1  0.052303           0.917513
# 2  0.053397           0.914161
# 3  0.035588           0.883238
# 4  0.068170           0.867124
#
# 📈 数据统计:
#          new_index  concentration  temperature        yield         cost  \
# count  1728.000000    1728.000000  1728.000000  1728.000000  1728.000000
# mean    863.500000       0.103333   105.000000    19.374705     0.135069
# std     498.974949       0.039274    12.250994    24.603949     0.111972
# min       0.000000       0.057000    90.000000     0.000000     0.020659
# 25%     431.750000       0.057000    90.000000     0.000000     0.051642
# 50%     863.500000       0.100000   105.000000     8.050000     0.098352
# 75%    1295.250000       0.153000   120.000000    29.877500     0.155256
# max    1727.000000       0.153000   120.000000   100.000000     0.483155
#
#        point_hypervolume
# count        1728.000000
# mean            0.145966
# std             0.204715
# min             0.000000
# 25%             0.000000
# 50%             0.042808
# 75%             0.220941
# max             0.929802

# %%
# 分析参数列和目标列
parameter_columns = ['base', 'ligand', 'solvent', 'concentration', 'temperature']
objective_columns = ['yield', 'cost','point_hypervolume']

print("🔍 参数列分析:")
for col in parameter_columns:
    unique_values = df[col].unique()
    print(f"  {col}: {len(unique_values)}个唯一值")
    if len(unique_values) <= 12:
        print(f"    值: {list(unique_values)}")
    else:
        print(f"    值范围: {min(unique_values)} - {max(unique_values)}")

print("\n🎯 目标列分析:")
for col in objective_columns:
    print(f"  {col}: 范围 {df[col].min():.3f} - {df[col].max():.3f}, 均值 {df[col].mean():.3f}")
# Out:
# 🔍 参数列分析:
#   base: 4个唯一值
#     值: ['KOPiv', 'KOAc', 'CsOAc', 'CsOPiv']
#   ligand: 12个唯一值
#     值: ['CgMe-PPh', 'PPh3', 'X-Phos', 'P(fur)3', 'GorlosPhos HBF4', 'PCy3 HBF4', 'BrettPhos', 'tBPh-CPhos', 'PPh2Me', 'PPhtBu2', 'JackiePhos', 'PPhMe2']
#   solvent: 4个唯一值
#     值: ['DMAc', 'BuCN', 'p-Xylene', 'BuOAc']
#   concentration: 3个唯一值
#     值: [0.153, 0.057, 0.1]
#   temperature: 3个唯一值
#     值: [120, 105, 90]
#
# 🎯 目标列分析:
#   yield: 范围 0.000 - 100.000, 均值 19.375
#   cost: 范围 0.021 - 0.483, 均值 0.135
#   point_hypervolume: 范围 0.000 - 0.930, 均值 0.146

# %%
import json
import numpy as np

def build_parameter_space(df, parameter_columns):
    """根据数据构建参数空间 - 所有参数都是choice类型"""
    parameter_space = []
    
    for col in parameter_columns:
        unique_values = df[col].unique()
        
        # 转换成原生 Python 类型，避免 np.int64 / np.float64 报错
        converted_values = [v.item() if isinstance(v, (np.generic,)) else v for v in unique_values]
        
        parameter_space.append({
            "name": col,
            "type": "choice",
            "values": converted_values
        })
    
    return parameter_space

# 构建参数空间
parameter_space = build_parameter_space(df, parameter_columns)
print("🔧 构建的参数空间:")
for param in parameter_space:
    print(f"  {param['name']}: {param['type']} - {param['values']}")

print(f"\n📋 参数空间JSON格式:")
print(json.dumps(parameter_space, indent=2, ensure_ascii=False))
# Out:
# 🔧 构建的参数空间:
#   base: choice - ['KOPiv', 'KOAc', 'CsOAc', 'CsOPiv']
#   ligand: choice - ['CgMe-PPh', 'PPh3', 'X-Phos', 'P(fur)3', 'GorlosPhos HBF4', 'PCy3 HBF4', 'BrettPhos', 'tBPh-CPhos', 'PPh2Me', 'PPhtBu2', 'JackiePhos', 'PPhMe2']
#   solvent: choice - ['DMAc', 'BuCN', 'p-Xylene', 'BuOAc']
#   concentration: choice - [0.153, 0.057, 0.1]
#   temperature: choice - [120, 105, 90]
#
# 📋 参数空间JSON格式:
# [
#   {
#     "name": "base",
#     "type": "choice",
#     "values": [
#       "KOPiv",
#       "KOAc",
#       "CsOAc",
#       "CsOPiv"
#     ]
#   },
#   {
#     "name": "ligand",
#     "type": "choice",
#     "values": [
#       "CgMe-PPh",
#       "PPh3",
#       "X-Phos",
#       "P(fur)3",
#       "GorlosPhos HBF4",
#       "PCy3 HBF4",
#       "BrettPhos",
#       "tBPh-CPhos",
#       "PPh2Me",
#       "PPhtBu2",
#       "JackiePhos",
#       "PPhMe2"
#     ]
#   },
#   {
#     "name": "solvent",
#     "type": "choice",
#     "values": [
#       "DMAc",
#       "BuCN",
#       "p-Xylene",
#       "BuOAc"
#     ]
#   },
#   {
#     "name": "concentration",
#     "type": "choice",
#     "values": [
#       0.153,
#       0.057,
#       0.1
#     ]
#   },
#   {
#     "name": "temperature",
#     "type": "choice",
#     "values": [
#       120,
#       105,
#       90
#     ]
#   }
# ]

# %%
# 定义优化目标
objectives = {
    "point_hypervolume": {"minimize": False}  # 最大化hv
        # 最小化成本
}

print("🎯 优化目标:")
for obj, config in objectives.items():
    direction = "最小化" if config["minimize"] else "最大化"
    print(f"  {obj}: {direction}")

# 目标权重（可选）
objective_weights = {
    "yield": 0.7,  # 产率权重70%
    "cost": 0.3    # 成本权重30%
}

print(f"\n⚖️ 目标权重: {objective_weights}")

# 保存配置供后续使用
config = {
    'parameter_space': parameter_space,
    'objectives': objectives,
    'objective_weights': objective_weights,
    'parameter_columns': parameter_columns,
    'objective_columns': objective_columns
}

print("\n✅ 配置已保存，可以进入下一步测试API接口")
# Out:
# 🎯 优化目标:
#   point_hypervolume: 最大化
#
# ⚖️ 目标权重: {'yield': 0.7, 'cost': 0.3}
#
# ✅ 配置已保存，可以进入下一步测试API接口

# %%
import requests
import time

# API配置
API_BASE_URL = "http://localhost:3320"
INIT_ENDPOINT = f"{API_BASE_URL}/init"
UPDATE_ENDPOINT = f"{API_BASE_URL}/update"

print("🔧 API配置:")
print(f"   基础URL: {API_BASE_URL}")
print(f"   Init接口: {INIT_ENDPOINT}")
print(f"   Update接口: {UPDATE_ENDPOINT}")

# 测试API连接
def test_api_connection():
    """测试API连接"""
    try:
        response = requests.get(f"{API_BASE_URL}/docs")
        if response.status_code == 200:
            print("✅ API服务器连接正常")
            return True
        else:
            print(f"❌ API服务器响应异常: {response.status_code}")
            return False
    except Exception as e:
        print(f"❌ API连接失败: {str(e)}")
        return False

# 测试连接
api_connected = test_api_connection()
if not api_connected:
    print("⚠️ 请确保API服务器正在运行: python api_parameter_optimizer_v3.py")
# Out:
# 🔧 API配置:
#    基础URL: http://localhost:3320
#    Init接口: http://localhost:3320/init
#    Update接口: http://localhost:3320/update
# ✅ API服务器连接正常

# %%
def call_init_api(parameter_space, objectives, batch_size=5, seed=42):
    """调用init接口初始化优化器"""
    
    # 构建请求数据
    init_request = {
        "parameter_space": parameter_space,
        "objectives": list(objectives.keys()),
        "batch": batch_size,
        "seed": seed,
        "sampling_method": "lhs"  # 使用sobol采样
    }
    
    print(f"🚀 调用init接口，批次大小: {batch_size}")
    print(f"�� 请求数据: {json.dumps(init_request, indent=2, ensure_ascii=False)}")
    
    try:
        response = requests.post(INIT_ENDPOINT, json=init_request)
        
        if response.status_code == 200:
            result = response.json()
            print(f"✅ Init接口调用成功")
            print(f"�� 采样方法: {result['sampling_method']}")
            print(f"📈 生成参数组合数: {len(result['results'])}")
            print(f"💬 消息: {result['message']}")
            return result
        else:
            print(f"❌ Init接口调用失败: {response.status_code}")
            print(f"📄 错误信息: {response.text}")
            return None
            
    except Exception as e:
        print(f"❌ Init接口调用异常: {str(e)}")
        return None

# 调用init接口
init_result = call_init_api(parameter_space, objectives, batch_size=5)

if init_result:
    print("\n�� 生成的参数组合:")
    for i, params in enumerate(init_result['results'], 1):
        print(f"  {i}. {params}")
# Out:
# 🚀 调用init接口，批次大小: 5
# �� 请求数据: {
#   "parameter_space": [
#     {
#       "name": "base",
#       "type": "choice",
#       "values": [
#         "KOPiv",
#         "KOAc",
#         "CsOAc",
#         "CsOPiv"
#       ]
#     },
#     {
#       "name": "ligand",
#       "type": "choice",
#       "values": [
#         "CgMe-PPh",
#         "PPh3",
#         "X-Phos",
#         "P(fur)3",
#         "GorlosPhos HBF4",
#         "PCy3 HBF4",
#         "BrettPhos",
#         "tBPh-CPhos",
#         "PPh2Me",
#         "PPhtBu2",
#         "JackiePhos",
#         "PPhMe2"
#       ]
#     },
#     {
#       "name": "solvent",
#       "type": "choice",
#       "values": [
#         "DMAc",
#         "BuCN",
#         "p-Xylene",
#         "BuOAc"
#       ]
#     },
#     {
#       "name": "concentration",
#       "type": "choice",
#       "values": [
#         0.153,
#         0.057,
#         0.1
#       ]
#     },
#     {
#       "name": "temperature",
#       "type": "choice",
#       "values": [
#         120,
#         105,
#         90
#       ]
#     }
#   ],
#   "objectives": [
#     "point_hypervolume"
#   ],
#   "batch": 5,
#   "seed": 42,
#   "sampling_method": "lhs"
# }
# ✅ Init接口调用成功
# �� 采样方法: lhs
# 📈 生成参数组合数: 5
# 💬 消息: 初始化成功，使用lhs采样生成5个参数组合
#
# �� 生成的参数组合:
#   1. {'base': 'CsOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90}
#   2. {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120}
#   3. {'base': 'KOAc', 'ligand': 'PPhtBu2', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120}
#   4. {'base': 'CsOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90}
#   5. {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105}

# %%
def simulate_experiment_results(params_list, df, random_seed=42):
    """从真实数据中查找完全匹配的实验结果"""
    # 设置随机种子确保结果一致性
    np.random.seed(random_seed)
    
    results = []
    
    for params in params_list:
        # 构建精确匹配的查询条件
        query_conditions = []
        for key, value in params.items():
            # 所有参数都进行精确匹配
            if isinstance(value, str):
                query_conditions.append(f"{key} == '{value}'")
            else:
                query_conditions.append(f"{key} == {value}")
        
        # 构建查询字符串
        query_str = " and ".join(query_conditions)
        
        try:
            # 查找完全匹配的数据
            matched_data = df.query(query_str)
            
            if len(matched_data) > 0:
                # 取第一个匹配的结果
                row = matched_data.iloc[0]
                experiment_result = {
                    "parameters": params,
                    "metrics": {
                        "yield": float(row['yield']),
                        "cost": float(row['cost']),
                        "point_hypervolume": float(row['point_hypervolume'])
                    }
                }
                results.append(experiment_result)
                print(f"✅ 找到完全匹配: {params} -> yield={row['yield']:.2f}, cost={row['cost']:.3f}，point_hypervolume={row['point_hypervolume']:.3f}")
            else:
                # 没有找到完全匹配，尝试查找最接近的参数组合
                print(f"⚠️ 未找到完全匹配: {params}")
                print(f"   尝试查找最接近的参数组合...")
                
                # 计算每个参数的距离
                best_match = None
                min_distance = float('inf')
                
                for _, row in df.iterrows():
                    distance = 0
                    match = True
                    
                    for key, target_value in params.items():
                        actual_value = row[key]
                        
                        if key in ['base', 'ligand', 'solvent']:
                            # 类别参数必须完全匹配
                            if actual_value != target_value:
                                match = False
                                break
                        else:
                            # 数值参数计算距离
                            distance += abs(actual_value - target_value)
                    
                    if match and distance < min_distance:
                        min_distance = distance
                        best_match = row
                
                if best_match is not None:
                    experiment_result = {
                        "parameters": params,
                        "metrics": {
                            "yield": float(best_match['yield']),
                            "cost": float(best_match['cost'])
                        }
                    }
                    results.append(experiment_result)
                    print(f"✅ 找到最接近匹配: {params} -> yield={best_match['yield']:.2f}, cost={best_match['cost']:.3f}")
                else:
                    print(f"❌ 未找到任何匹配: {params}")
                    # 如果实在找不到，使用随机结果（这种情况应该很少）
                    random_row = df.sample(1, random_state=random_seed).iloc[0]
                    experiment_result = {
                        "parameters": params,
                        "metrics": {
                            "yield": float(random_row['yield']),
                            "cost": float(random_row['cost'])
                        }
                    }
                    results.append(experiment_result)
                    print(f"⚠️ 使用随机结果: {params} -> yield={random_row['yield']:.2f}, cost={random_row['cost']:.3f}")
                
        except Exception as e:
            print(f"❌ 查询失败: {str(e)}")
            # 使用随机结果
            random_row = df.sample(1, random_state=random_seed).iloc[0]
            experiment_result = {
                "parameters": params,
                "metrics": {
                    "yield": float(random_row['yield']),
                    "cost": float(random_row['cost'])
                }
            }
            results.append(experiment_result)
    
    return results

# 模拟第一轮实验结果
if 'init_result' in locals() and init_result:
    print("\n🧪 模拟第一轮实验结果:")
    first_round_results = simulate_experiment_results(init_result['results'], df)
    
    print("\n�� 第一轮实验结果:")
    for i, result in enumerate(first_round_results, 1):
        params = result['parameters']
        metrics = result['metrics']
        print(f"  {i}. 参数: {params}")
        print(f"     结果: yield={metrics['yield']:.2f}, cost={metrics['cost']:.3f}，point_hypervolume={metrics['point_hypervolume']:.3f}")
# Out:
# 🧪 模拟第一轮实验结果:
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=17.98, cost=0.084，point_hypervolume=0.155
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=76.59, cost=0.264，point_hypervolume=0.362
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhtBu2', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120} -> yield=0.00, cost=0.084，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90} -> yield=0.00, cost=0.122，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=0.48, cost=0.039，point_hypervolume=0.005
#
# �� 第一轮实验结果:
#   1. 参数: {'base': 'CsOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90}
#      结果: yield=17.98, cost=0.084，point_hypervolume=0.155
#   2. 参数: {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120}
#      结果: yield=76.59, cost=0.264，point_hypervolume=0.362
#   3. 参数: {'base': 'KOAc', 'ligand': 'PPhtBu2', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120}
#      结果: yield=0.00, cost=0.084，point_hypervolume=0.000
#   4. 参数: {'base': 'CsOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90}
#      结果: yield=0.00, cost=0.122，point_hypervolume=0.000
#   5. 参数: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105}
#      结果: yield=0.48, cost=0.039，point_hypervolume=0.005

# %%
def call_update_api(parameter_space, objectives, completed_experiments, batch_size=3, use_weights=False):
    """调用update接口进行贝叶斯优化"""
    
    # 构建请求数据
    update_request = {
        "parameter_space": parameter_space,
        "objectives": objectives,
        "completed_experiments": completed_experiments,
        "batch": batch_size,
        "use_weights": use_weights,
        "objective_weights": objective_weights if use_weights else None,
        "additional_metrics": ["yield", "cost"]
    }
    
    print(f"�� 调用update接口，批次大小: {batch_size}")
    print(f"📊 已完成实验数: {len(completed_experiments)}")
    print(f"⚖️ 使用权重: {use_weights}")
    
    try:
        response = requests.post(UPDATE_ENDPOINT, json=update_request)
        
        if response.status_code == 200:
            result = response.json()
            print(f"✅ Update接口调用成功")
            print(f"📈 推荐参数组合数: {len(result['results'])}")
            print(f"💬 消息: {result['message']}")
            return result
        else:
            print(f"❌ Update接口调用失败: {response.status_code}")
            print(f"📄 错误信息: {response.text}")
            return None
            
    except Exception as e:
        print(f"❌ Update接口调用异常: {str(e)}")
        return None

# 调用update接口
if 'first_round_results' in locals():
    update_result = call_update_api(parameter_space, objectives, first_round_results, batch_size=3)
    
    if update_result:
        print("\n🔍 推荐的下一轮参数组合:")
        for i, params in enumerate(update_result['results'], 1):
            print(f"  {i}. {params}")
# Out:
# �� 调用update接口，批次大小: 3
# 📊 已完成实验数: 5
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 3
# 💬 消息: 成功推荐3个参数组合，使用默认配置
#
# 🔍 推荐的下一轮参数组合:
#   1. {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120}
#   2. {'base': 'KOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120}
#   3. {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120}

# %%
def run_optimization_loop(parameter_space, objectives, df, n_rounds=8, init_batch=10, update_batch=10):
    """运行多轮优化循环"""
    
    all_experiments = []
    optimization_history = []
    
    print(f"🔄 开始{n_rounds}轮优化循环")
    print(f"📊 初始批次: {init_batch}, 更新批次: {update_batch}")
    
    # 第一轮：初始化
    print("\n=== 第1轮：初始化 ===")
    init_result = call_init_api(parameter_space, objectives, batch_size=init_batch,seed=42)
    
    if not init_result:
        print("❌ 初始化失败，退出优化循环")
        return None, None
    
    # 模拟第一轮实验结果
    round_results = simulate_experiment_results(init_result['results'], df)
    all_experiments.extend(round_results)
    
    # 记录历史
    optimization_history.append({
        'round': 1,
        'type': 'init',
        'parameters': init_result['results'],
        'results': round_results,
        'best_yield': max([r['metrics']['yield'] for r in round_results]),
        'best_cost': min([r['metrics']['cost'] for r in round_results])
    })
    
    print(f"📈 第1轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
    
    # 后续轮次：贝叶斯优化
    for round_num in range(2, n_rounds + 1):
        print(f"\n=== 第{round_num}轮：贝叶斯优化 ===")
        
        # 调用update接口
        update_result = call_update_api(parameter_space, objectives, all_experiments, batch_size=update_batch)
        
        if not update_result:
            print(f"❌ 第{round_num}轮更新失败，退出优化循环")
            break
        
        # 模拟实验结果
        round_results = simulate_experiment_results(update_result['results'], df)
        all_experiments.extend(round_results)
        
        # 记录历史
        optimization_history.append({
            'round': round_num,
            'type': 'update',
            'parameters': update_result['results'],
            'results': round_results,
            'best_yield': max([r['metrics']['yield'] for r in round_results]),
            'best_cost': min([r['metrics']['cost'] for r in round_results])
        })
        
        print(f"�� 第{round_num}轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
        
        # 添加延迟，避免请求过快
        # time.sleep(1)
    
    return all_experiments, optimization_history

# 运行优化循环
all_experiments, optimization_history = run_optimization_loop(parameter_space, objectives, df)
# Out:
# 🔄 开始8轮优化循环
# 📊 初始批次: 10, 更新批次: 10
#
# === 第1轮：初始化 ===
# 🚀 调用init接口，批次大小: 10
# �� 请求数据: {
#   "parameter_space": [
#     {
#       "name": "base",
#       "type": "choice",
#       "values": [
#         "KOPiv",
#         "KOAc",
#         "CsOAc",
#         "CsOPiv"
#       ]
#     },
#     {
#       "name": "ligand",
#       "type": "choice",
#       "values": [
#         "CgMe-PPh",
#         "PPh3",
#         "X-Phos",
#         "P(fur)3",
#         "GorlosPhos HBF4",
#         "PCy3 HBF4",
#         "BrettPhos",
#         "tBPh-CPhos",
#         "PPh2Me",
#         "PPhtBu2",
#         "JackiePhos",
#         "PPhMe2"
#       ]
#     },
#     {
#       "name": "solvent",
#       "type": "choice",
#       "values": [
#         "DMAc",
#         "BuCN",
#         "p-Xylene",
#         "BuOAc"
#       ]
#     },
#     {
#       "name": "concentration",
#       "type": "choice",
#       "values": [
#         0.153,
#         0.057,
#         0.1
#       ]
#     },
#     {
#       "name": "temperature",
#       "type": "choice",
#       "values": [
#         120,
#         105,
#         90
#       ]
#     }
#   ],
#   "objectives": [
#     "point_hypervolume"
#   ],
#   "batch": 10,
#   "seed": 42,
#   "sampling_method": "lhs"
# }
# ✅ Init接口调用成功
# �� 采样方法: lhs
# 📈 生成参数组合数: 10
# 💬 消息: 初始化成功，使用lhs采样生成10个参数组合
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=55.96, cost=0.278，point_hypervolume=0.248
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=87.59, cost=0.057，point_hypervolume=0.807
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105} -> yield=64.62, cost=0.047，point_hypervolume=0.610
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=6.77, cost=0.398，point_hypervolume=0.012
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=13.78, cost=0.125，point_hypervolume=0.107
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=1.37, cost=0.038，point_hypervolume=0.013
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105} -> yield=6.77, cost=0.067，point_hypervolume=0.061
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.127，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=26.29, cost=0.229，point_hypervolume=0.144
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhtBu2', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=0.00, cost=0.086，point_hypervolume=0.000
# 📈 第1轮最佳结果: yield=87.59, cost=0.038
#
# === 第2轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 10
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 90} -> yield=42.30, cost=0.045，point_hypervolume=0.400
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=50.79, cost=0.163，point_hypervolume=0.352
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=14.92, cost=0.270，point_hypervolume=0.069
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90} -> yield=38.12, cost=0.147，point_hypervolume=0.277
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.280，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=37.36, cost=0.147，point_hypervolume=0.271
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90} -> yield=39.50, cost=0.163，point_hypervolume=0.274
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=20.87, cost=0.270，point_hypervolume=0.096
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=18.55, cost=0.148，point_hypervolume=0.134
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=0.00, cost=0.145，point_hypervolume=0.000
# �� 第2轮最佳结果: yield=50.79, cost=0.045
#
# === 第3轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 20
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.89, cost=0.140，point_hypervolume=0.007
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=0.00, cost=0.155，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=5.03, cost=0.146，point_hypervolume=0.037
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=43.12, cost=0.350，point_hypervolume=0.124
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=36.29, cost=0.048，point_hypervolume=0.342
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'GorlosPhos HBF4', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=14.06, cost=0.034，point_hypervolume=0.137
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.26, cost=0.145，point_hypervolume=0.002
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=3.14, cost=0.156，point_hypervolume=0.022
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=75.12, cost=0.356，point_hypervolume=0.206
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=5.95, cost=0.141，point_hypervolume=0.044
# �� 第3轮最佳结果: yield=75.12, cost=0.034
#
# === 第4轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 30
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=62.75, cost=0.067，point_hypervolume=0.565
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=99.81, cost=0.052，point_hypervolume=0.930
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=89.95, cost=0.067，point_hypervolume=0.809
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=83.22, cost=0.058，point_hypervolume=0.765
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=61.09, cost=0.052，point_hypervolume=0.569
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=98.38, cost=0.053，point_hypervolume=0.914
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=96.64, cost=0.068，point_hypervolume=0.867
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=30.41, cost=0.068，point_hypervolume=0.273
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=55.70, cost=0.057，point_hypervolume=0.513
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=28.90, cost=0.053，point_hypervolume=0.269
# �� 第4轮最佳结果: yield=99.81, cost=0.052
#
# === 第5轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 40
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=44.47, cost=0.054，point_hypervolume=0.413
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=45.73, cost=0.060，point_hypervolume=0.418
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 120} -> yield=46.42, cost=0.088，point_hypervolume=0.396
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=31.14, cost=0.072，point_hypervolume=0.277
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=52.47, cost=0.061，point_hypervolume=0.479
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=60.29, cost=0.055，point_hypervolume=0.558
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=26.39, cost=0.071，point_hypervolume=0.235
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 120} -> yield=19.71, cost=0.175，point_hypervolume=0.132
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 120} -> yield=33.69, cost=0.087，point_hypervolume=0.288
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=95.48, cost=0.114，point_hypervolume=0.763
# �� 第5轮最佳结果: yield=95.48, cost=0.054
#
# === 第6轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 50
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=99.22, cost=0.099，point_hypervolume=0.824
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=92.03, cost=0.155，point_hypervolume=0.654
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=91.19, cost=0.101，point_hypervolume=0.754
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 90} -> yield=62.34, cost=0.151，point_hypervolume=0.447
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=92.19, cost=0.140，point_hypervolume=0.685
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=59.05, cost=0.124，point_hypervolume=0.458
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90} -> yield=46.57, cost=0.124，point_hypervolume=0.361
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 120} -> yield=22.87, cost=0.151，point_hypervolume=0.164
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=81.66, cost=0.084，point_hypervolume=0.705
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=2.79, cost=0.092，point_hypervolume=0.024
# �� 第6轮最佳结果: yield=99.22, cost=0.084
#
# === 第7轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 60
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=98.49, cost=0.052，point_hypervolume=0.918
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 105} -> yield=90.39, cost=0.067，point_hypervolume=0.813
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105} -> yield=80.69, cost=0.100，point_hypervolume=0.668
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=59.82, cost=0.118，point_hypervolume=0.473
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=79.76, cost=0.129，point_hypervolume=0.611
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=40.06, cost=0.116，point_hypervolume=0.318
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=100.00, cost=0.099，point_hypervolume=0.831
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=48.91, cost=0.037，point_hypervolume=0.472
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=84.48, cost=0.076，point_hypervolume=0.744
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=41.10, cost=0.118，point_hypervolume=0.325
# �� 第7轮最佳结果: yield=100.00, cost=0.037
#
# === 第8轮：贝叶斯优化 ===
# �� 调用update接口，批次大小: 10
# 📊 已完成实验数: 70
# ⚖️ 使用权重: False
# ✅ Update接口调用成功
# 📈 推荐参数组合数: 10
# 💬 消息: 成功推荐10个参数组合，使用默认配置
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105} -> yield=12.54, cost=0.075，point_hypervolume=0.111
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=86.14, cost=0.076，point_hypervolume=0.759
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 120} -> yield=78.60, cost=0.042，point_hypervolume=0.749
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 90} -> yield=0.00, cost=0.087，point_hypervolume=0.000
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=66.03, cost=0.077，point_hypervolume=0.580
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=56.57, cost=0.053，point_hypervolume=0.526
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=70.80, cost=0.077，point_hypervolume=0.621
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 90} -> yield=84.17, cost=0.080，point_hypervolume=0.733
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=50.93, cost=0.052，point_hypervolume=0.475
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 90} -> yield=18.72, cost=0.075，point_hypervolume=0.165
# �� 第8轮最佳结果: yield=86.14, cost=0.042

# %%
# 将优化历史结果保存到CSV文件
def save_optimization_history_to_csv(optimization_history, filename="optimization_results.csv"):
    """将优化历史结果保存到CSV文件"""
    
    if not optimization_history:
        print("❌ 没有优化历史数据可保存")
        return
    
    # 准备数据
    csv_data = []
    
    for round_data in optimization_history:
        round_num = round_data['round']
        round_type = round_data['type']
        best_yield = round_data['best_yield']
        best_cost = round_data['best_cost']
        
        # 为每个参数组合创建一行
        for i, (params, result) in enumerate(zip(round_data['parameters'], round_data['results'])):
            row = {
                'round': round_num,
                'type': round_type,
                'experiment_id': f"R{round_num}_E{i+1}",
                'base': params['base'],
                'ligand': params['ligand'],
                'solvent': params['solvent'],
                'concentration': params['concentration'],
                'temperature': params['temperature'],
                'yield': result['metrics']['yield'],
                'cost': result['metrics']['cost'],
                'best_yield_in_round': best_yield,
                'best_cost_in_round': best_cost,
                'point_hypervolume': result['metrics']['point_hypervolume']     
            }
            csv_data.append(row)
    
    # 创建DataFrame并保存
    df_results = pd.DataFrame(csv_data)
    
    # 保存到CSV
    df_results.to_csv(filename, index=False, encoding='utf-8')
    
    print(f"✅ 优化结果已保存到: {filename}")
    print(f"📊 共保存 {len(df_results)} 个实验结果")
    print(f"🔄 包含 {len(optimization_history)} 轮优化")
    
    # 显示数据预览
    print("\n📋 数据预览:")
    print(df_results.head())
    
    # 显示统计信息
    print("\n📈 统计信息:")
    print(f"  总实验数: {len(df_results)}")
    print(f"  总轮次: {df_results['round'].nunique()}")
    print(f"  最佳产率: {df_results['yield'].max():.2f}")
    print(f"  最佳成本: {df_results['cost'].min():.3f}")
    print(f"  平均产率: {df_results['yield'].mean():.2f}")
    print(f"  平均成本: {df_results['cost'].mean():.3f}")
    
    return df_results

# 保存优化结果
if 'optimization_history' in locals() and optimization_history:
    print("💾 保存优化历史结果到CSV文件...")
    results_df = save_optimization_history_to_csv(optimization_history, "bayesian_optimization_results.csv")
    
    # 额外保存汇总数据
    summary_data = []
    for round_data in optimization_history:
        summary_row = {
            'round': round_data['round'],
            'type': round_data['type'],
            'experiments_count': len(round_data['parameters']),
            'best_yield': round_data['best_yield'],
            'best_cost': round_data['best_cost'],
            'avg_yield': np.mean([r['metrics']['yield'] for r in round_data['results']]),
            'avg_cost': np.mean([r['metrics']['cost'] for r in round_data['results']])
        }
        summary_data.append(summary_row)
    
    summary_df = pd.DataFrame(summary_data)
    summary_df.to_csv("optimization_summary.csv", index=False, encoding='utf-8')
    print("✅ 优化汇总数据已保存到: optimization_summary.csv")
    
    print("\n�� 生成的文件:")
    print("  - bayesian_optimization_results.csv: 详细实验结果")
    print("  - optimization_summary.csv: 轮次汇总数据")
    
else:
    print("❌ 没有找到optimization_history数据，请先运行优化循环")
# Out:
# 💾 保存优化历史结果到CSV文件...
# ✅ 优化结果已保存到: bayesian_optimization_results.csv
# 📊 共保存 80 个实验结果
# 🔄 包含 8 轮优化
#
# 📋 数据预览:
#    round  type experiment_id    base           ligand   solvent  \
# 0      1  init         R1_E1   KOPiv       tBPh-CPhos      DMAc
# 1      1  init         R1_E2   KOPiv         CgMe-PPh      DMAc
# 2      1  init         R1_E3    KOAc           X-Phos     BuOAc
# 3      1  init         R1_E4   CsOAc       JackiePhos  p-Xylene
# 4      1  init         R1_E5  CsOPiv  GorlosPhos HBF4      DMAc
#
#    concentration  temperature  yield      cost  best_yield_in_round  \
# 0          0.057          120  55.96  0.278107                87.59
# 1          0.100          120  87.59  0.056922                87.59
# 2          0.100          105  64.62  0.046569                87.59
# 3          0.153           90   6.77  0.398459                87.59
# 4          0.100           90  13.78  0.124819                87.59
#
#    best_cost_in_round
# 0            0.038402
# 1            0.038402
# 2            0.038402
# 3            0.038402
# 4            0.038402
#
# 📈 统计信息:
#   总实验数: 80
#   总轮次: 8
#   最佳产率: 100.00
#   最佳成本: 0.034
#   平均产率: 47.13
#   平均成本: 0.114
# ✅ 优化汇总数据已保存到: optimization_summary.csv
#
# �� 生成的文件:
#   - bayesian_optimization_results.csv: 详细实验结果
#   - optimization_summary.csv: 轮次汇总数据

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
results_df
# Out:
#     round    type experiment_id    base           ligand   solvent  \
# 0       1    init         R1_E1   KOPiv       tBPh-CPhos      DMAc
# 1       1    init         R1_E2   KOPiv         CgMe-PPh      DMAc
# 2       1    init         R1_E3    KOAc           X-Phos     BuOAc
# 3       1    init         R1_E4   CsOAc       JackiePhos  p-Xylene
# 4       1    init         R1_E5  CsOPiv  GorlosPhos HBF4      DMAc
# 5       1    init         R1_E6   KOPiv        PCy3 HBF4      BuCN
# 6       1    init         R1_E7    KOAc             PPh3      BuCN
# 7       1    init         R1_E8  CsOPiv           PPhMe2     BuOAc
# 8       1    init         R1_E9  CsOPiv        BrettPhos  p-Xylene
# 9       1    init        R1_E10   CsOAc          PPhtBu2  p-Xylene
# 10      2  update         R2_E1   KOPiv           X-Phos     BuOAc
# 11      2  update         R2_E2   KOPiv        BrettPhos      BuCN
# 12      2  update         R2_E3   KOPiv       tBPh-CPhos  p-Xylene
# 13      2  update         R2_E4   KOPiv        BrettPhos  p-Xylene
# 14      2  update         R2_E5   KOPiv       tBPh-CPhos     BuOAc
# 15      2  update         R2_E6   KOPiv        BrettPhos  p-Xylene
# 16      2  update         R2_E7   KOPiv        BrettPhos      BuCN
# 17      2  update         R2_E8   KOPiv       tBPh-CPhos  p-Xylene
# 18      2  update         R2_E9    KOAc        BrettPhos  p-Xylene
# 19      2  update        R2_E10   KOPiv        BrettPhos      DMAc
# 20      3  update         R3_E1   KOPiv        BrettPhos      DMAc
# 21      3  update         R3_E2   KOPiv        BrettPhos      DMAc
# 22      3  update         R3_E3    KOAc        BrettPhos      DMAc
# 23      3  update         R3_E4   KOPiv       JackiePhos      DMAc
# 24      3  update         R3_E5   KOPiv  GorlosPhos HBF4      DMAc
# 25      3  update         R3_E6    KOAc  GorlosPhos HBF4      DMAc
# 26      3  update         R3_E7   KOPiv        BrettPhos      DMAc
# 27      3  update         R3_E8    KOAc        BrettPhos      DMAc
# 28      3  update         R3_E9    KOAc       JackiePhos      DMAc
# 29      3  update        R3_E10    KOAc        BrettPhos      DMAc
# 30      4  update         R4_E1   KOPiv         CgMe-PPh      DMAc
# 31      4  update         R4_E2   KOPiv         CgMe-PPh      DMAc
# 32      4  update         R4_E3   KOPiv         CgMe-PPh      DMAc
# 33      4  update         R4_E4    KOAc         CgMe-PPh      DMAc
# 34      4  update         R4_E5   KOPiv         CgMe-PPh      DMAc
# 35      4  update         R4_E6    KOAc         CgMe-PPh      DMAc
# 36      4  update         R4_E7    KOAc         CgMe-PPh      DMAc
# 37      4  update         R4_E8    KOAc         CgMe-PPh      DMAc
# 38      4  update         R4_E9   KOPiv         CgMe-PPh      DMAc
# 39      4  update        R4_E10    KOAc         CgMe-PPh      DMAc
# 40      5  update         R5_E1   KOPiv         CgMe-PPh  p-Xylene
# 41      5  update         R5_E2   KOPiv         CgMe-PPh     BuOAc
# 42      5  update         R5_E3    KOAc         CgMe-PPh     BuOAc
# 43      5  update         R5_E4    KOAc         CgMe-PPh  p-Xylene
# 44      5  update         R5_E5    KOAc         CgMe-PPh     BuOAc
# 45      5  update         R5_E6    KOAc         CgMe-PPh  p-Xylene
# 46      5  update         R5_E7   KOPiv         CgMe-PPh  p-Xylene
# 47      5  update         R5_E8  CsOPiv         CgMe-PPh     BuOAc
# 48      5  update         R5_E9   KOPiv         CgMe-PPh     BuOAc
# 49      5  update        R5_E10   CsOAc         CgMe-PPh      DMAc
# 50      6  update         R6_E1   CsOAc         CgMe-PPh      DMAc
# 51      6  update         R6_E2  CsOPiv         CgMe-PPh      DMAc
# 52      6  update         R6_E3   CsOAc         CgMe-PPh  p-Xylene
# 53      6  update         R6_E4  CsOPiv           X-Phos     BuOAc
# 54      6  update         R6_E5  CsOPiv         CgMe-PPh      DMAc
# 55      6  update         R6_E6  CsOPiv           X-Phos     BuOAc
# 56      6  update         R6_E7  CsOPiv           X-Phos     BuOAc
# 57      6  update         R6_E8  CsOPiv           X-Phos     BuOAc
# 58      6  update         R6_E9   CsOAc           X-Phos     BuOAc
# 59      6  update        R6_E10   CsOAc           X-Phos     BuOAc
# 60      7  update         R7_E1   KOPiv         CgMe-PPh      DMAc
# 61      7  update         R7_E2   KOPiv         CgMe-PPh      DMAc
# 62      7  update         R7_E3   CsOAc         CgMe-PPh  p-Xylene
# 63      7  update         R7_E4   CsOAc         CgMe-PPh  p-Xylene
# 64      7  update         R7_E5  CsOPiv           X-Phos      BuCN
# 65      7  update         R7_E6  CsOPiv           X-Phos      DMAc
# 66      7  update         R7_E7   CsOAc         CgMe-PPh      DMAc
# 67      7  update         R7_E8   KOPiv           X-Phos     BuOAc
# 68      7  update         R7_E9   CsOAc           X-Phos      DMAc
# 69      7  update        R7_E10   CsOAc         CgMe-PPh  p-Xylene
# 70      8  update         R8_E1    KOAc           X-Phos      BuCN
# 71      8  update         R8_E2   CsOAc           X-Phos      DMAc
# 72      8  update         R8_E3    KOAc           X-Phos      BuCN
# 73      8  update         R8_E4   CsOAc           X-Phos      BuCN
# 74      8  update         R8_E5   CsOAc           X-Phos  p-Xylene
# 75      8  update         R8_E6    KOAc           X-Phos      BuCN
# 76      8  update         R8_E7   CsOAc           X-Phos  p-Xylene
# 77      8  update         R8_E8   CsOAc           X-Phos      DMAc
# 78      8  update         R8_E9   KOPiv           X-Phos      BuCN
# 79      8  update        R8_E10    KOAc           X-Phos      BuCN
#
#     concentration  temperature   yield      cost  best_yield_in_round  \
# 0           0.057          120   55.96  0.278107                87.59
# 1           0.100          120   87.59  0.056922                87.59
# 2           0.100          105   64.62  0.046569                87.59
# 3           0.153           90    6.77  0.398459                87.59
# 4           0.100           90   13.78  0.124819                87.59
# 5           0.153          105    1.37  0.038402                87.59
# 6           0.057          105    6.77  0.067024                87.59
# 7           0.100          120    0.00  0.126697                87.59
# 8           0.153          120   26.29  0.229152                87.59
# 9           0.153           90    0.00  0.085624                87.59
# 10          0.100           90   42.30  0.045349                50.79
# 11          0.100          120   50.79  0.162878                50.79
# 12          0.100          105   14.92  0.270199                50.79
# 13          0.100           90   38.12  0.147131                50.79
# 14          0.100          120    0.00  0.279535                50.79
# 15          0.100          120   37.36  0.147128                50.79
# 16          0.100           90   39.50  0.162791                50.79
# 17          0.100          120   20.87  0.270221                50.79
# 18          0.100          120   18.55  0.148154                50.79
# 19          0.100           90    0.00  0.144665                50.79
# 20          0.153          120    0.89  0.140017                75.12
# 21          0.057          120    0.00  0.154793                75.12
# 22          0.100          120    5.03  0.145774                75.12
# 23          0.153          120   43.12  0.350391                75.12
# 24          0.057          120   36.29  0.047543                75.12
# 25          0.153          120   14.06  0.033796                75.12
# 26          0.100          120    0.26  0.144666                75.12
# 27          0.057          120    3.14  0.155896                75.12
# 28          0.100          120   75.12  0.356228                75.12
# 29          0.153          120    5.95  0.141126                75.12
# 30          0.057           90   62.75  0.066978                99.81
# 31          0.153          120   99.81  0.052307                99.81
# 32          0.057          120   89.95  0.067056                99.81
# 33          0.100          120   83.22  0.058004                99.81
# 34          0.153           90   61.09  0.052195                99.81
# 35          0.153          120   98.38  0.053397                99.81
# 36          0.057          120   96.64  0.068170                99.81
# 37          0.057           90   30.41  0.067979                99.81
# 38          0.100           90   55.70  0.056830                99.81
# 39          0.153           90   28.90  0.053196                99.81
# 40          0.153          120   44.47  0.053754                95.48
# 41          0.153          120   45.73  0.060122                95.48
# 42          0.057          120   46.42  0.088299                95.48
# 43          0.057          120   31.14  0.071972                95.48
# 44          0.153          120   52.47  0.061254                95.48
# 45          0.153          120   60.29  0.054906                95.48
# 46          0.057          120   26.39  0.070861                95.48
# 47          0.057          120   19.71  0.174523                95.48
# 48          0.057          120   33.69  0.087133                95.48
# 49          0.057          120   95.48  0.113667                95.48
# 50          0.153          120   99.22  0.098900                99.22
# 51          0.057          120   92.03  0.154530                99.22
# 52          0.153          120   91.19  0.100520                99.22
# 53          0.057           90   62.34  0.151488                99.22
# 54          0.153          120   92.19  0.139753                99.22
# 55          0.153          120   59.05  0.124390                99.22
# 56          0.153           90   46.57  0.124320                99.22
# 57          0.057          120   22.87  0.151266                99.22
# 58          0.153          105   81.66  0.083644                99.22
# 59          0.100          120    2.79  0.091722                99.22
# 60          0.153          105   98.49  0.052303               100.00
# 61          0.057          105   90.39  0.067058               100.00
# 62          0.153          105   80.69  0.100481               100.00
# 63          0.057          120   59.82  0.117577               100.00
# 64          0.153          105   79.76  0.128801               100.00
# 65          0.153          105   40.06  0.116328               100.00
# 66          0.153          105  100.00  0.098902               100.00
# 67          0.153          120   48.91  0.036865               100.00
# 68          0.153          105   84.48  0.075583               100.00
# 69          0.057          105   41.10  0.117509               100.00
# 70          0.057          105   12.54  0.075266                86.14
# 71          0.153           90   86.14  0.075587                86.14
# 72          0.153          120   78.60  0.042419                86.14
# 73          0.153           90    0.00  0.087316                86.14
# 74          0.153           90   66.03  0.077153                86.14
# 75          0.100          120   56.57  0.052746                86.14
# 76          0.153          120   70.80  0.077171                86.14
# 77          0.100           90   84.17  0.080232                86.14
# 78          0.100          120   50.93  0.051608                86.14
# 79          0.057           90   18.72  0.075313                86.14
#
#     best_cost_in_round
# 0             0.038402
# 1             0.038402
# 2             0.038402
# 3             0.038402
# 4             0.038402
# 5             0.038402
# 6             0.038402
# 7             0.038402
# 8             0.038402
# 9             0.038402
# 10            0.045349
# 11            0.045349
# 12            0.045349
# 13            0.045349
# 14            0.045349
# 15            0.045349
# 16            0.045349
# 17            0.045349
# 18            0.045349
# 19            0.045349
# 20            0.033796
# 21            0.033796
# 22            0.033796
# 23            0.033796
# 24            0.033796
# 25            0.033796
# 26            0.033796
# 27            0.033796
# 28            0.033796
# 29            0.033796
# 30            0.052195
# 31            0.052195
# 32            0.052195
# 33            0.052195
# 34            0.052195
# 35            0.052195
# 36            0.052195
# 37            0.052195
# 38            0.052195
# 39            0.052195
# 40            0.053754
# 41            0.053754
# 42            0.053754
# 43            0.053754
# 44            0.053754
# 45            0.053754
# 46            0.053754
# 47            0.053754
# 48            0.053754
# 49            0.053754
# 50            0.083644
# 51            0.083644
# 52            0.083644
# 53            0.083644
# 54            0.083644
# 55            0.083644
# 56            0.083644
# 57            0.083644
# 58            0.083644
# 59            0.083644
# 60            0.036865
# 61            0.036865
# 62            0.036865
# 63            0.036865
# 64            0.036865
# 65            0.036865
# 66            0.036865
# 67            0.036865
# 68            0.036865
# 69            0.036865
# 70            0.042419
# 71            0.042419
# 72            0.042419
# 73            0.042419
# 74            0.042419
# 75            0.042419
# 76            0.042419
# 77            0.042419
# 78            0.042419
# 79            0.042419
