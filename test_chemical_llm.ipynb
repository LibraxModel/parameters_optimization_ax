# %%
import pandas as pd
import numpy as np
import os
import sys
import json
import requests
import time
import copy
sys.path.insert(0, '/root/sxw/edit')

from LLINBO_agent import (
    ProblemContext, Parameter, PriorExperiment, 
    LLMConfig, LLINBOAgent
)

# 设置环境变量
os.environ.setdefault("OPENAI_API_KEY", "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")
os.environ.setdefault("HTTP_PROXY", "http://127.0.0.1:7890")
os.environ.setdefault("HTTPS_PROXY", "http://127.0.0.1:7890")

print("✅ 库导入完成")
# Out:
# ✅ 库导入完成

# %%
def load_chemical_data(csv_path: str):
    """加载化学实验数据"""
    df = pd.read_csv(csv_path)
    return df


def build_parameter_space(df: pd.DataFrame):
    """构建参数空间定义"""
    parameters = [
        Parameter(
            name="base",
            type="choice",
            values=sorted(df["base"].unique().tolist()),
            value_type="str",
            description="碱基类型",
        ),
        Parameter(
            name="ligand",
            type="choice",
            values=sorted(df["ligand"].unique().tolist()),
            value_type="str",
            description="配体类型",
        ),
        Parameter(
            name="solvent",
            type="choice",
            values=sorted(df["solvent"].unique().tolist()),
            value_type="str",
            description="溶剂类型",
        ),
        Parameter(
            name="concentration",
            type="choice",
            values=sorted(df["concentration"].unique().tolist()),
            value_type="float",
            description="反应浓度 (M)",
        ),
        Parameter(
            name="temperature",
            type="choice",
            values=sorted(df["temperature"].unique().tolist()),
            value_type="int",
            description="反应温度 (°C)",
        ),
    ]
    return parameters


def convert_parameters_to_api_format(parameters):
    """将 LLINBO Parameter 转换为 API ParameterSpace 格式"""
    api_params = []
    for param in parameters:
        api_param = {
            "name": param.name,
            "type": param.type,
            "values": param.values
        }
        api_params.append(api_param)
    return api_params


def call_init_api(parameter_space, objectives, batch_size=20, seed=None, api_url="http://localhost:3320"):
    """调用 init 接口进行采样"""
    init_endpoint = f"{api_url}/init"
    
    # 转换参数空间格式
    api_parameter_space = convert_parameters_to_api_format(parameter_space)
    
    # 构建请求数据
    init_request = {
        "parameter_space": api_parameter_space,
        "objectives": list(objectives.keys()),
        "batch": batch_size,
        "seed": seed,
        "sampling_method": "lhs"  # 使用 lhs 采样
    }
    
    print(f"🚀 调用 init 接口，批次大小: {batch_size}")
    
    try:
        response = requests.post(init_endpoint, json=init_request, timeout=30)
        
        if response.status_code == 200:
            result = response.json()
            print(f"✅ Init 接口调用成功")
            print(f"📈 生成参数组合数: {len(result['results'])}")
            print(f"💬 消息: {result['message']}")
            return result
        else:
            print(f"❌ Init 接口调用失败: {response.status_code}")
            print(f"📄 错误信息: {response.text}")
            return None
            
    except Exception as e:
        print(f"❌ Init 接口调用异常: {str(e)}")
        return None


def simulate_experiment_results(params_list, df, random_seed=None):
    """从真实数据中查找完全匹配的实验结果"""
    if random_seed is not None:
        np.random.seed(random_seed)
    
    results = []
    
    for params in params_list:
        # 构建精确匹配的查询条件
        query_conditions = []
        for key, value in params.items():
            if isinstance(value, str):
                query_conditions.append(f"{key} == '{value}'")
            else:
                query_conditions.append(f"{key} == {value}")
        
        # 构建查询字符串
        query_str = " and ".join(query_conditions)
        
        try:
            # 查找完全匹配的数据
            matched_data = df.query(query_str)
            
            if len(matched_data) > 0:
                # 取第一个匹配的结果
                row = matched_data.iloc[0]
                experiment_result = {
                    "parameters": params,
                    "metrics": {
                        "yield": float(row['yield']),
                        "cost": float(row['cost'])
                    }
                }
                results.append(experiment_result)
                print(f"✅ 找到完全匹配: {params} -> yield={row['yield']:.2f}, cost={row['cost']:.3f}")
            else:
                print(f"⚠️ 未找到完全匹配: {params}")
                # 如果找不到，使用随机结果
                random_row = df.sample(1, random_state=random_seed).iloc[0]
                experiment_result = {
                    "parameters": params,
                    "metrics": {
                        "yield": float(random_row['yield']),
                        "cost": float(random_row['cost'])
                    }
                }
                results.append(experiment_result)
                print(f"⚠️ 使用随机结果: {params} -> yield={random_row['yield']:.2f}, cost={random_row['cost']:.3f}")
                
        except Exception as e:
            print(f"❌ 查询失败: {str(e)}")
            # 使用随机结果
            random_row = df.sample(1, random_state=random_seed).iloc[0]
            experiment_result = {
                "parameters": params,
                "metrics": {
                    "yield": float(random_row['yield']),
                    "cost": float(random_row['cost'])
                }
            }
            results.append(experiment_result)
    
    return results


def convert_experiment_results_to_prior_experiments(experiment_results):
    """将实验结果转换为 PriorExperiment 格式"""
    prior_experiments = []
    for result in experiment_results:
        exp = PriorExperiment(
            parameters=result["parameters"],
            metrics=result["metrics"]
        )
        prior_experiments.append(exp)
    return prior_experiments


def create_prior_experiments(df: pd.DataFrame, parameters, objectives, n_samples: int = 50, 
                             api_url: str = "http://localhost:3320", seed: int = None):
    """使用 init 接口进行采样，创建先验实验数据"""
    print(f"\n📚 使用 init 接口进行采样，生成 {n_samples} 个先验实验数据...")
    
    # 调用 init 接口进行采样
    init_result = call_init_api(parameters, objectives, batch_size=n_samples, seed=seed, api_url=api_url)
    
    if not init_result:
        print("⚠️ Init 接口调用失败，使用随机采样作为备选方案")
        # 备选方案：随机采样
        sample_df = df.sample(n=min(n_samples, len(df)), random_state=seed)
        prior_experiments = []
        for _, row in sample_df.iterrows():
            exp = PriorExperiment(
                parameters={
                    "base": str(row["base"]),
                    "ligand": str(row["ligand"]),
                    "solvent": str(row["solvent"]),
                    "concentration": float(row["concentration"]),
                    "temperature": int(row["temperature"]),
                },
                metrics={
                    "yield": float(row["yield"]),
                    "cost": float(row["cost"]),
                }
            )
            prior_experiments.append(exp)
        return prior_experiments
    
    # 从数据集中查找匹配的实验结果
    print(f"\n🔍 从数据集中查找匹配的实验结果...")
    experiment_results = simulate_experiment_results(init_result['results'], df, random_seed=seed)
    
    # 转换为 PriorExperiment 格式
    prior_experiments = convert_experiment_results_to_prior_experiments(experiment_results)
    
    print(f"✅ 成功创建 {len(prior_experiments)} 个先验实验数据")
    
    return prior_experiments

print("✅ 辅助函数定义完成")
# Out:
# ✅ 辅助函数定义完成

# %%
csv_path = "test/1728_BMS_experiments_yield_and_cost.csv"
print(f"📊 加载数据集: {csv_path}")
df = load_chemical_data(csv_path)
print(f"✅ 数据集加载成功: {len(df)} 个实验数据")
# Out:
# 📊 加载数据集: test/1728_BMS_experiments_yield_and_cost.csv
# ✅ 数据集加载成功: 1728 个实验数据

# %%
problem_context = ProblemContext(
    problem_description="优化 Pd 催化的 C-H 芳基化反应条件，反应物为 N1-甲基-1H-咪唑-4-甲腈和 1-溴-2-氟苯",
    industry="化学合成 - 有机反应优化",
    domain_knowledge="""
    这是一个 Pd 催化的 C-H 芳基化反应优化问题。
    - 碱基（base）影响反应活性和选择性
    - 配体（ligand）对催化剂活性和选择性至关重要
    - 溶剂（solvent）影响反应速率和产物选择性
    - 浓度（concentration）影响反应速率和副反应
    - 温度（temperature）影响反应速率和选择性
    优化目标是同时最大化产率（yield）和最小化成本（cost）。
    """,
    constraints=[
        "所有推荐的参数组合必须符合基本化学常识"
    ],
    optimization_goals=[
        "最大化产率（yield）",
        "最小化成本（cost）"
    ]
)
print("✅ 问题背景定义完成")
# Out:
# ✅ 问题背景定义完成

# %%
print("\n🔧 构建参数空间...")
parameters = build_parameter_space(df)
print(f"✅ 参数空间定义完成: {len(parameters)} 个参数")
for param in parameters:
    print(f"   - {param.name}: {len(param.values)} 个可选值")


# ## 4. 定义优化目标

# %%
objectives = {
    "yield": {"minimize": False},  # 最大化产率
    "cost": {"minimize": True}      # 最小化成本
}
print("✅ 优化目标定义完成")
print(f"   - yield: 最大化")
print(f"   - cost: 最小化")
# Out:
# 🔧 构建参数空间...
# ✅ 参数空间定义完成: 5 个参数
#    - base: 4 个可选值
#    - ligand: 12 个可选值
#    - solvent: 4 个可选值
#    - concentration: 3 个可选值
#    - temperature: 3 个可选值
# ✅ 优化目标定义完成
#    - yield: 最大化
#    - cost: 最小化

# %%
print("\n📚 创建先验实验数据...")
prior_experiments = create_prior_experiments(
    df, parameters, objectives, 
    n_samples=20,  # 初始批次大小
    api_url="http://localhost:3320",
    seed=42
)
print(f"✅ 先验实验数据: {len(prior_experiments)} 个实验")
# Out:
# 📚 创建先验实验数据...
#
# 📚 使用 init 接口进行采样，生成 20 个先验实验数据...
# 🚀 调用 init 接口，批次大小: 20
# ✅ Init 接口调用成功
# 📈 生成参数组合数: 20
# 💬 消息: 初始化成功，使用lhs采样生成20个参数组合
#
# 🔍 从数据集中查找匹配的实验结果...
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PCy3 HBF4', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=3.40, cost=0.042
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhtBu2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=0.00, cost=0.045
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105} -> yield=6.00, cost=0.186
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'tBPh-CPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90} -> yield=20.04, cost=0.317
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 90} -> yield=11.65, cost=0.483
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=0.00, cost=0.118
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=29.17, cost=0.147
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 90} -> yield=0.76, cost=0.139
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 120} -> yield=12.19, cost=0.066
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=0.00, cost=0.088
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=84.03, cost=0.140
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhtBu2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.055
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=0.00, cost=0.034
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=7.82, cost=0.368
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPh2Me', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.085
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'P(fur)3', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 120} -> yield=23.80, cost=0.035
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PCy3 HBF4', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=2.15, cost=0.085
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=38.79, cost=0.030
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 105} -> yield=29.16, cost=0.121
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'GorlosPhos HBF4', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=16.77, cost=0.094
# ✅ 成功创建 20 个先验实验数据
# ✅ 先验实验数据: 20 个实验

# %%
yield_values = [exp.metrics["yield"] for exp in prior_experiments]
cost_values = [exp.metrics["cost"] for exp in prior_experiments]
print(f"   产率范围: [{min(yield_values):.2f}, {max(yield_values):.2f}], 平均值: {sum(yield_values)/len(yield_values):.2f}")
print(f"   成本范围: [{min(cost_values):.4f}, {max(cost_values):.4f}], 平均值: {sum(cost_values)/len(cost_values):.4f}")
# Out:
#    产率范围: [0.00, 84.03], 平均值: 14.29
#    成本范围: [0.0300, 0.4832], 平均值: 0.1339

# %%
print("\n🤖 初始化 LLINBO Agent...")
llm_config = LLMConfig(
    model_name="gpt-5",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://api.openai.com/v1"
)

agent = LLINBOAgent(
    problem_context=problem_context,
    parameters=parameters,
    objectives=objectives,
    llm_config=llm_config,
    prior_experiments=prior_experiments
)
print("✅ LLINBO Agent 初始化完成")
# Out:
# 🤖 初始化 LLINBO Agent...
# ✅ LLINBO Agent 初始化完成

# %%
print("\n🎯 生成优化建议...")
num_suggestions = 5
suggestions = agent.suggest_parameters(num_suggestions=num_suggestions, print_prompt=True)
print(f"✅ 成功生成 {len(suggestions)} 个建议")
# Out:
# 🎯 生成优化建议...
#
# ================================================================================
# 📝 输入大模型的完整提示词:
# ================================================================================
# # 优化问题背景
# **问题描述**: 优化 Pd 催化的 C-H 芳基化反应条件，反应物为 N1-甲基-1H-咪唑-4-甲腈和 1-溴-2-氟苯
# **行业领域**: 化学合成 - 有机反应优化
# **领域知识**:
#     这是一个 Pd 催化的 C-H 芳基化反应优化问题。
#     - 碱基（base）影响反应活性和选择性
#     - 配体（ligand）对催化剂活性和选择性至关重要
#     - 溶剂（solvent）影响反应速率和产物选择性
#     - 浓度（concentration）影响反应速率和副反应
#     - 温度（temperature）影响反应速率和选择性
#     优化目标是同时最大化产率（yield）和最小化成本（cost）。
#
# **约束条件**: 所有推荐的参数组合必须符合基本化学常识
# **优化目标**: 最大化产率（yield）, 最小化成本（cost）
#
# # 参数空间定义
# 以下是需要优化的参数及其范围：
#
# **重要提示**：如果参数是离散参数，必须从列出的可选值中选择，不能选择其他值；如果参数是连续参数，值必须在 [最小值, 最大值] 范围内。
# 1. **base**
#    描述: 碱基类型
#    类型: 离散参数（必须从以下值中选择一个）
#    可选值列表: [CsOAc, CsOPiv, KOAc, KOPiv]
#    可选值数量: 4 个
#    ⚠️ 重要：只能选择列表中的值，不能选择其他值或中间值
#    值类型: str
# 2. **ligand**
#    描述: 配体类型
#    类型: 离散参数（必须从以下值中选择一个）
#    可选值列表: [BrettPhos, CgMe-PPh, GorlosPhos HBF4, JackiePhos, P(fur)3, PCy3 HBF4, PPh2Me, PPh3, PPhMe2, PPhtBu2, X-Phos, tBPh-CPhos]
#    可选值数量: 12 个
#    ⚠️ 重要：只能选择列表中的值，不能选择其他值或中间值
#    值类型: str
# 3. **solvent**
#    描述: 溶剂类型
#    类型: 离散参数（必须从以下值中选择一个）
#    可选值列表: [BuCN, BuOAc, DMAc, p-Xylene]
#    可选值数量: 4 个
#    ⚠️ 重要：只能选择列表中的值，不能选择其他值或中间值
#    值类型: str
# 4. **concentration**
#    描述: 反应浓度 (M)
#    类型: 离散参数（必须从以下值中选择一个）
#    可选值列表: [0.057, 0.1, 0.153]
#    可选值数量: 3 个
#    ⚠️ 重要：只能选择列表中的值，不能选择其他值或中间值
#    值类型: float
# 5. **temperature**
#    描述: 反应温度 (°C)
#    类型: 离散参数（必须从以下值中选择一个）
#    可选值列表: [90, 105, 120]
#    可选值数量: 3 个
#    ⚠️ 重要：只能选择列表中的值，不能选择其他值或中间值
#    值类型: int
#
# # 优化目标
# 需要优化的指标及其方向：
# - **yield**: 最大化 (maximize)
# - **cost**: 最小化 (minimize)
#
# **注意**: 这是多目标优化问题，需要平衡多个目标。
#
# # 先验实验数据
# 以下是 20 个历史实验结果：
#
# ```
#  实验编号   base          ligand  solvent  concentration  temperature  yield     cost
#     1   KOAc       PCy3 HBF4     DMAc          0.057           90   3.40 0.042297
#     2  KOPiv         PPhtBu2    BuOAc          0.153          105   0.00 0.045302
#     3   KOAc       BrettPhos     BuCN          0.057          105   6.00 0.186486
#     4  CsOAc      tBPh-CPhos p-Xylene          0.100           90  20.04 0.316812
#     5 CsOPiv      JackiePhos     BuCN          0.057           90  11.65 0.483155
#     6 CsOPiv          PPhMe2    BuOAc          0.153          105   0.00 0.118175
#     7  KOPiv       BrettPhos p-Xylene          0.100          105  29.17 0.147098
#     8 CsOPiv GorlosPhos HBF4 p-Xylene          0.057           90   0.76 0.138877
#     9  KOPiv            PPh3     BuCN          0.057          120  12.19 0.065971
#    10  CsOAc          PPhMe2 p-Xylene          0.057          105   0.00 0.088202
#    11 CsOPiv        CgMe-PPh     DMAc          0.153           90  84.03 0.139729
#    12   KOAc         PPhtBu2    BuOAc          0.100          120   0.00 0.054918
#    13  KOPiv          PPh2Me     BuCN          0.153          105   0.00 0.033582
#    14   KOAc      JackiePhos    BuOAc          0.100          120   7.82 0.367772
#    15  CsOAc          PPh2Me    BuOAc          0.100          120   0.00 0.084568
#    16  KOPiv         P(fur)3 p-Xylene          0.153          120  23.80 0.034507
#    17  CsOAc       PCy3 HBF4     BuCN          0.153          105   2.15 0.085003
#    18   KOAc          X-Phos     DMAc          0.153           90  38.79 0.029950
#    19 CsOPiv          X-Phos     DMAc          0.100          105  29.16 0.120947
#    20  CsOAc GorlosPhos HBF4     DMAc          0.057          120  16.77 0.094082
# ```
#
# # 优化任务
# 基于以上信息，请推荐 5 个参数配置用于下一步实验。
#
# **优化方向要求**：
# - **yield**: 需要**最大化**，优先选择能提高该指标值的参数组合
# - **cost**: 需要**最小化**，优先选择能降低该指标值的参数组合
#
# **其他要求**：
# 1. **参数值必须严格符合定义**：
#    - 对于连续参数（range类型），值必须在 [最小值, 最大值] 范围内
#    - 对于离散参数（choice类型），值必须**完全等于**可选值列表中的某个值，不能是其他值
#    - 例如：如果可选值是 ['A', 'B', 'C', 'D']，则只能选择这4个值之一
# 2. 如果你有80%的把握你所推荐的参数组合得到的实验结果会比先验数据中的最好的结果更好，才推荐这个参数组合。
# 3. 考虑先验数据中的模式和趋势
# 4. 在探索（exploration）和利用（exploitation）之间取得平衡
# 5. 如果存在多个目标，需要考虑多目标优化（帕累托最优）
# 6. ⚠️警告！你的推荐必须根据先验数据以及你拥有的行业背景知识进行推理，不能直接推荐先验数据中已有的点。
# 7. ⚠️警告！你的推荐不能与先验数据重复。推荐的参数组合一定不能已存在于先验数据中
#
# 请以 JSON 格式返回推荐的参数配置，格式如下：
# ```json
# {
#   "suggestions": [
#     {
#       "参数名1": 值1,
#       "参数名2": 值2,
#       ...
#     }
#   ]
# }
# ```
# ================================================================================
#
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 5 个建议

# %%
print(f"\n📊 生成的优化建议 ({len(suggestions)} 个):")
print("=" * 80)
for i, suggestion in enumerate(suggestions, 1):
    print(f"\n建议 {i}:")
    for param_name, param_value in suggestion.items():
        print(f"  {param_name}: {param_value}")
        # 如果 param_name 是主要参数，查找实验结果
        if param_name == list(suggestion.keys())[-1]:
            # 查找是否在数据集中有匹配的实验结果
            mask = (
                (df["base"] == suggestion.get("base")) &
                (df["ligand"] == suggestion.get("ligand")) &
                (df["solvent"] == suggestion.get("solvent")) &
                (df["concentration"] == suggestion.get("concentration")) &
                (df["temperature"] == suggestion.get("temperature"))
            )
            matching_rows = df[mask]
            if len(matching_rows) > 0:
                row = matching_rows.iloc[0]
                print(f"    ▶ 实验结果: 产率={row['yield']:.2f}%, 成本={row['cost']:.4f}")
            else:
                print("    ▶ 无匹配的实验结果（新组合）")
# Out:
# 📊 生成的优化建议 (5 个):
# ================================================================================
#
# 建议 1:
#   base: CsOPiv
#   ligand: CgMe-PPh
#   solvent: DMAc
#   concentration: 0.153
#   temperature: 105
#     ▶ 实验结果: 产率=100.00%, 成本=0.1398
#
# 建议 2:
#   base: CsOPiv
#   ligand: CgMe-PPh
#   solvent: DMAc
#   concentration: 0.1
#   temperature: 90
#     ▶ 实验结果: 产率=75.28%, 成本=0.1444
#
# 建议 3:
#   base: CsOPiv
#   ligand: CgMe-PPh
#   solvent: BuCN
#   concentration: 0.153
#   temperature: 90
#     ▶ 实验结果: 产率=36.73%, 成本=0.1517
#
# 建议 4:
#   base: KOPiv
#   ligand: CgMe-PPh
#   solvent: DMAc
#   concentration: 0.153
#   temperature: 90
#     ▶ 实验结果: 产率=61.09%, 成本=0.0522
#
# 建议 5:
#   base: CsOAc
#   ligand: CgMe-PPh
#   solvent: DMAc
#   concentration: 0.153
#   temperature: 90
#     ▶ 实验结果: 产率=43.84%, 成本=0.0987

# %%
# ## 初始化多轮测试参数

# %%
# 重新加载数据（如果需要）
csv_path = "test/1728_BMS_experiments_yield_and_cost.csv"
df_multi = load_chemical_data(csv_path)
parameters_multi = build_parameter_space(df_multi)
objectives_multi = {
    "yield": {"minimize": False},  # 最大化产率
    "cost": {"minimize": True}      # 最小化成本
}

problem_context_multi = ProblemContext(
    problem_description="优化 Pd 催化的 C-H 芳基化反应条件，反应物为 N1-甲基-1H-咪唑-4-甲腈和 1-溴-2-氟苯",
    industry="化学合成 - 有机反应优化",
    domain_knowledge="""
    这是一个 Pd 催化的 C-H 芳基化反应优化问题。
    - 碱基（base）影响反应活性和选择性
    - 配体（ligand）对催化剂活性和选择性至关重要
    - 溶剂（solvent）影响反应速率和产物选择性
    - 浓度（concentration）影响反应速率和副反应
    - 温度（temperature）影响反应速率和选择性
    优化目标是同时最大化产率（yield）和最小化成本（cost）。
    """,
    constraints=[
            "所有推荐的参数组合必须符合基本化学常识"

    ],
    optimization_goals=[
        "最大化产率（yield）",
        "最小化成本（cost）"
    ]
)

# 多轮测试配置
n_rounds = 20
init_batch = 10
update_batch = 3
api_url = "http://localhost:3320"
seed = 42

print("✅ 多轮测试参数初始化完成")
print(f"   总轮次: {n_rounds}")
print(f"   初始批次: {init_batch}")
print(f"   更新批次: {update_batch}")

# %% [markdown]
# ## 定义多轮优化函数

# %%
# Out:
# ✅ 多轮测试参数初始化完成
#    总轮次: 20
#    初始批次: 10
#    更新批次: 3

# %%
def run_llinbo_optimization(df, parameters, objectives, problem_context, 
                           n_rounds=10, init_batch=20, update_batch=3, 
                           api_url="http://localhost:3320", seed=42):
    """使用 LLINBO Agent 进行多轮优化，仿照 notebook 的方式"""
    
    print(f"\n🔄 开始 {n_rounds} 轮优化循环（使用 LLINBO Agent）")
    print(f"📊 初始批次: {init_batch}, 更新批次: {update_batch}")
    
    all_experiments = []
    optimization_history = []
    
    # 第一轮：初始化（使用 init 接口）
    print(f"\n=== 第 1 轮：初始化 ===")
    init_result = call_init_api(parameters, objectives, batch_size=init_batch, seed=seed, api_url=api_url)
    
    if not init_result:
        print("❌ 初始化失败，退出优化循环")
        return None, None
    
    # 模拟第一轮实验结果
    round_results = simulate_experiment_results(init_result['results'], df, random_seed=seed)
    round_prior_experiments = convert_experiment_results_to_prior_experiments(round_results)
    all_experiments.extend(round_prior_experiments)
    
    # 记录历史
    optimization_history.append({
        'round': 1,
        'type': 'init',
        'parameters': init_result['results'],
        'results': round_results,
        'best_yield': max([r['metrics']['yield'] for r in round_results]),
        'best_cost': min([r['metrics']['cost'] for r in round_results])
    })
    
    print(f"📈 第 1 轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
    
    # 后续轮次：使用 LLINBO Agent（代替 update 接口）
    for round_num in range(2, n_rounds + 1):
        print(f"\n=== 第 {round_num} 轮：LLINBO 优化 ===")
        
        # 重要：在创建 agent 之前，确认上一轮的结果已经加入
        # 显示当前先验数据数量（确认数据已更新）
        print(f"📊 当前先验实验数据数量: {len(all_experiments)} 个")
        if len(all_experiments) > 0:
            # 显示最近几轮的数据，确认包含上一轮的结果
            recent_count = min(5, len(all_experiments))
            recent_yields = [exp.metrics["yield"] for exp in all_experiments[-recent_count:]]
            recent_costs = [exp.metrics["cost"] for exp in all_experiments[-recent_count:]]
            print(f"   最近 {recent_count} 个实验的产率: {[f'{y:.2f}' for y in recent_yields]}")
            print(f"   最近 {recent_count} 个实验的成本: {[f'{c:.4f}' for c in recent_costs]}")
            
            # 显示上一轮（第 round_num-1 轮）的结果是否在当前先验数据中
            if round_num > 2:
                prev_round_history = [h for h in optimization_history if h['round'] == round_num - 1]
                if prev_round_history:
                    prev_round_params = prev_round_history[0]['parameters']
                    print(f"   🔍 检查上一轮（第 {round_num-1} 轮）的结果是否在先验数据中:")
                    for i, prev_param in enumerate(prev_round_params, 1):
                        # 检查这个参数组合是否在 all_experiments 中
                        found = False
                        for exp in all_experiments:
                            if all(exp.parameters.get(k) == prev_param.get(k) for k in prev_param.keys()):
                                found = True
                                print(f"      上一轮建议 {i}: ✅ 已在先验数据中 (yield={exp.metrics['yield']:.2f}, cost={exp.metrics['cost']:.4f})")
                                break
                        if not found:
                            print(f"      上一轮建议 {i}: ❌ 未在先验数据中！")
        
        # 创建 LLINBO Agent（使用当前所有实验数据作为先验）
        # 重要：确保使用更新后的 all_experiments（包含之前所有轮次的结果）
        # 使用深拷贝确保数据独立
        prior_experiments_for_agent = copy.deepcopy(all_experiments)
        
        print(f"🔧 创建 LLINBO Agent，使用 {len(prior_experiments_for_agent)} 个先验实验数据")
        
        llm_config = LLMConfig(
            model_name="gpt-5-mini",
            api_key=os.getenv("OPENAI_API_KEY"),
            base_url="https://api.openai.com/v1"
        )
        
        # 创建新的 agent，传入更新后的先验数据
        agent = LLINBOAgent(
            problem_context=problem_context,
            parameters=parameters,
            objectives=objectives,
            llm_config=llm_config,
            prior_experiments=prior_experiments_for_agent  # 使用深拷贝，确保数据正确传递
        )
        
        # 验证 agent 中的先验数据数量
        print(f"✅ Agent 创建完成，Agent 中的先验数据数量: {len(agent.prior_experiments)} 个")
        
        # 生成优化建议（LLINBO Agent 代替 update 接口）
        print(f"🤖 使用 LLINBO Agent 生成 {update_batch} 个优化建议...")
        
        # 添加延迟，确保不会因为请求过快导致问题
        time.sleep(0.5)  # 在请求前等待，避免请求过快
        
        suggestions = agent.suggest_parameters(num_suggestions=update_batch)
        
        if not suggestions:
            print(f"⚠️ 第 {round_num} 轮未能生成有效建议，跳过")
            continue
        
        print(f"✅ 成功生成 {len(suggestions)} 个建议")
        
        # 模拟实验结果
        round_results = simulate_experiment_results(suggestions, df, random_seed=seed)
        round_prior_experiments = convert_experiment_results_to_prior_experiments(round_results)
        
        # 重要：将本轮结果加入到先验数据中，供下一轮使用
        # 在加入之前，先检查是否有重复
        print(f"📝 准备将第 {round_num} 轮的 {len(round_prior_experiments)} 个实验结果加入到先验数据中")
        for i, new_exp in enumerate(round_prior_experiments, 1):
            # 检查是否已经存在相同的参数组合
            is_duplicate = False
            for existing_exp in all_experiments:
                if all(existing_exp.parameters.get(k) == new_exp.parameters.get(k) 
                       for k in new_exp.parameters.keys()):
                    is_duplicate = True
                    print(f"   ⚠️ 第 {round_num} 轮建议 {i} 的参数组合已存在于先验数据中，跳过重复添加")
                    break
            if not is_duplicate:
                all_experiments.append(new_exp)
                print(f"   ✅ 第 {round_num} 轮建议 {i} 已加入先验数据")
        
        print(f"📊 更新后的先验数据总数: {len(all_experiments)} 个")
        
        # 记录历史
        optimization_history.append({
            'round': round_num,
            'type': 'llinbo',
            'parameters': suggestions,
            'results': round_results,
            'best_yield': max([r['metrics']['yield'] for r in round_results]),
            'best_cost': min([r['metrics']['cost'] for r in round_results])
        })
        
        print(f"📈 第 {round_num} 轮最佳结果: yield={optimization_history[-1]['best_yield']:.2f}, cost={optimization_history[-1]['best_cost']:.3f}")
        
        # 显示本轮生成的建议详情（类似 main 函数中的显示）
        print(f"\n📋 第 {round_num} 轮生成的建议详情:")
        for i, suggestion in enumerate(suggestions, 1):
            print(f"  建议 {i}: {suggestion}")
        
        # 检查建议是否在数据集中（类似 main 函数中的检查）
        print(f"\n🔍 检查第 {round_num} 轮建议是否在原始数据集中:")
        for i, suggestion in enumerate(suggestions, 1):
            mask = (
                (df["base"] == suggestion["base"]) &
                (df["ligand"] == suggestion["ligand"]) &
                (df["solvent"] == suggestion["solvent"]) &
                (df["concentration"] == suggestion["concentration"]) &
                (df["temperature"] == suggestion["temperature"])
            )
            matching_rows = df[mask]
            
            if len(matching_rows) > 0:
                row = matching_rows.iloc[0]
                print(f"  建议 {i} - 在数据集中找到: yield={row['yield']:.2f}%, cost={row['cost']:.4f}")
            else:
                print(f"  建议 {i} - 不在数据集中（新组合）")
        
        # 添加延迟，避免请求过快
        time.sleep(1)
    
    return all_experiments, optimization_history

print("✅ 多轮优化函数定义完成")
# Out:
# ✅ 多轮优化函数定义完成

# %%
llinbo_experiments, llinbo_history = run_llinbo_optimization(
    df_multi, parameters_multi, objectives_multi, problem_context_multi,
    n_rounds=n_rounds,
    init_batch=init_batch,
    update_batch=update_batch,
    api_url=api_url,
    seed=seed
)
# Out:
# 🔄 开始 20 轮优化循环（使用 LLINBO Agent）
# 📊 初始批次: 10, 更新批次: 3
#
# === 第 1 轮：初始化 ===
# 🚀 调用 init 接口，批次大小: 10
# ✅ Init 接口调用成功
# 📈 生成参数组合数: 10
# 💬 消息: 初始化成功，使用lhs采样生成10个参数组合
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPh3', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90} -> yield=5.80, cost=0.090
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 90} -> yield=28.02, cost=0.199
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105} -> yield=4.53, cost=0.122
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=77.58, cost=0.045
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'P(fur)3', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 120} -> yield=53.11, cost=0.045
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.057, 'temperature': 105} -> yield=0.00, cost=0.108
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105} -> yield=24.00, cost=0.156
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=24.02, cost=0.265
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPh2Me', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=5.02, cost=0.036
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhtBu2', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=2.13, cost=0.053
# 📈 第 1 轮最佳结果: yield=77.58, cost=0.036
#
# === 第 2 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 10 个
#    最近 5 个实验的产率: ['0.00', '24.00', '24.02', '5.02', '2.13']
#    最近 5 个实验的成本: ['0.1079', '0.1560', '0.2648', '0.0364', '0.0533']
# 🔧 创建 LLINBO Agent，使用 10 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 10 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=6.73, cost=0.367
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPhMe2', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=0.00, cost=0.043
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=27.79, cost=0.116
# 📝 准备将第 2 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 2 轮建议 1 已加入先验数据
#    ✅ 第 2 轮建议 2 已加入先验数据
#    ✅ 第 2 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 13 个
# 📈 第 2 轮最佳结果: yield=27.79, cost=0.043
#
# 📋 第 2 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'PPhMe2', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90}
#
# 🔍 检查第 2 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=6.73%, cost=0.3667
#   建议 2 - 在数据集中找到: yield=0.00%, cost=0.0427
#   建议 3 - 在数据集中找到: yield=27.79%, cost=0.1163
#
# === 第 3 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 13 个
#    最近 5 个实验的产率: ['5.02', '2.13', '6.73', '0.00', '27.79']
#    最近 5 个实验的成本: ['0.0364', '0.0533', '0.3667', '0.0427', '0.1163']
#    🔍 检查上一轮（第 2 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=6.73, cost=0.3667)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=0.00, cost=0.0427)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=27.79, cost=0.1163)
# 🔧 创建 LLINBO Agent，使用 13 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 13 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=7.82, cost=0.368
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=32.37, cost=0.059
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=84.64, cost=0.123
# 📝 准备将第 3 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 3 轮建议 1 已加入先验数据
#    ✅ 第 3 轮建议 2 已加入先验数据
#    ✅ 第 3 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 16 个
# 📈 第 3 轮最佳结果: yield=84.64, cost=0.059
#
# 📋 第 3 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120}
#
# 🔍 检查第 3 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=7.82%, cost=0.3678
#   建议 2 - 在数据集中找到: yield=32.37%, cost=0.0591
#   建议 3 - 在数据集中找到: yield=84.64%, cost=0.1230
#
# === 第 4 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 16 个
#    最近 5 个实验的产率: ['0.00', '27.79', '7.82', '32.37', '84.64']
#    最近 5 个实验的成本: ['0.0427', '0.1163', '0.3678', '0.0591', '0.1230']
#    🔍 检查上一轮（第 3 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=7.82, cost=0.3678)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=32.37, cost=0.0591)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=84.64, cost=0.1230)
# 🔧 创建 LLINBO Agent，使用 16 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 16 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=46.75, cost=0.060
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=11.68, cost=0.350
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105} -> yield=0.00, cost=0.086
# 📝 准备将第 4 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 4 轮建议 1 已加入先验数据
#    ✅ 第 4 轮建议 2 已加入先验数据
#    ✅ 第 4 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 19 个
# 📈 第 4 轮最佳结果: yield=46.75, cost=0.060
#
# 📋 第 4 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOAc', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105}
#
# 🔍 检查第 4 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=46.75%, cost=0.0603
#   建议 2 - 在数据集中找到: yield=11.68%, cost=0.3503
#   建议 3 - 在数据集中找到: yield=0.00%, cost=0.0858
#
# === 第 5 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 19 个
#    最近 5 个实验的产率: ['32.37', '84.64', '46.75', '11.68', '0.00']
#    最近 5 个实验的成本: ['0.0591', '0.1230', '0.0603', '0.3503', '0.0858']
#    🔍 检查上一轮（第 4 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=46.75, cost=0.0603)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=11.68, cost=0.3503)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=0.00, cost=0.0858)
# 🔧 创建 LLINBO Agent，使用 19 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 19 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=46.75, cost=0.060
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 105} -> yield=0.00, cost=0.155
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90} -> yield=2.77, cost=0.446
# 📝 准备将第 5 轮的 3 个实验结果加入到先验数据中
#    ⚠️ 第 5 轮建议 1 的参数组合已存在于先验数据中，跳过重复添加
#    ✅ 第 5 轮建议 2 已加入先验数据
#    ✅ 第 5 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 21 个
# 📈 第 5 轮最佳结果: yield=46.75, cost=0.060
#
# 📋 第 5 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90}
#
# 🔍 检查第 5 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=46.75%, cost=0.0603
#   建议 2 - 在数据集中找到: yield=0.00%, cost=0.1548
#   建议 3 - 在数据集中找到: yield=2.77%, cost=0.4456
#
# === 第 6 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 21 个
#    最近 5 个实验的产率: ['46.75', '11.68', '0.00', '0.00', '2.77']
#    最近 5 个实验的成本: ['0.0603', '0.3503', '0.0858', '0.1548', '0.4456']
#    🔍 检查上一轮（第 5 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=46.75, cost=0.0603)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=0.00, cost=0.1548)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=2.77, cost=0.4456)
# 🔧 创建 LLINBO Agent，使用 21 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 21 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=32.37, cost=0.059
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=5.95, cost=0.141
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90} -> yield=13.01, cost=0.460
# 📝 准备将第 6 轮的 3 个实验结果加入到先验数据中
#    ⚠️ 第 6 轮建议 1 的参数组合已存在于先验数据中，跳过重复添加
#    ✅ 第 6 轮建议 2 已加入先验数据
#    ✅ 第 6 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 23 个
# 📈 第 6 轮最佳结果: yield=32.37, cost=0.059
#
# 📋 第 6 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#   建议 2: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90}
#
# 🔍 检查第 6 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=32.37%, cost=0.0591
#   建议 2 - 在数据集中找到: yield=5.95%, cost=0.1411
#   建议 3 - 在数据集中找到: yield=13.01%, cost=0.4603
#
# === 第 7 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 23 个
#    最近 5 个实验的产率: ['0.00', '0.00', '2.77', '5.95', '13.01']
#    最近 5 个实验的成本: ['0.0858', '0.1548', '0.4456', '0.1411', '0.4603']
#    🔍 检查上一轮（第 6 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=32.37, cost=0.0591)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=5.95, cost=0.1411)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=13.01, cost=0.4603)
# 🔧 创建 LLINBO Agent，使用 23 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 23 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPh2Me', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=10.51, cost=0.027
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105} -> yield=31.32, cost=0.054
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105} -> yield=2.41, cost=0.454
# 📝 准备将第 7 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 7 轮建议 1 已加入先验数据
#    ✅ 第 7 轮建议 2 已加入先验数据
#    ✅ 第 7 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 26 个
# 📈 第 7 轮最佳结果: yield=31.32, cost=0.027
#
# 📋 第 7 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'PPh2Me', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 105}
#
# 🔍 检查第 7 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=10.51%, cost=0.0274
#   建议 2 - 在数据集中找到: yield=31.32%, cost=0.0537
#   建议 3 - 在数据集中找到: yield=2.41%, cost=0.4541
#
# === 第 8 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 26 个
#    最近 5 个实验的产率: ['5.95', '13.01', '10.51', '31.32', '2.41']
#    最近 5 个实验的成本: ['0.1411', '0.4603', '0.0274', '0.0537', '0.4541']
#    🔍 检查上一轮（第 7 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=10.51, cost=0.0274)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=31.32, cost=0.0537)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=2.41, cost=0.4541)
# 🔧 创建 LLINBO Agent，使用 26 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 26 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=35.43, cost=0.049
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=5.36, cost=0.358
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=5.29, cost=0.365
# 📝 准备将第 8 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 8 轮建议 1 已加入先验数据
#    ✅ 第 8 轮建议 2 已加入先验数据
#    ✅ 第 8 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 29 个
# 📈 第 8 轮最佳结果: yield=35.43, cost=0.049
#
# 📋 第 8 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'GorlosPhos HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90}
#
# 🔍 检查第 8 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=35.43%, cost=0.0492
#   建议 2 - 在数据集中找到: yield=5.36%, cost=0.3584
#   建议 3 - 在数据集中找到: yield=5.29%, cost=0.3654
#
# === 第 9 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 29 个
#    最近 5 个实验的产率: ['31.32', '2.41', '35.43', '5.36', '5.29']
#    最近 5 个实验的成本: ['0.0537', '0.4541', '0.0492', '0.3584', '0.3654']
#    🔍 检查上一轮（第 8 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=35.43, cost=0.0492)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=5.36, cost=0.3584)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=5.29, cost=0.3654)
# 🔧 创建 LLINBO Agent，使用 29 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 29 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.039
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90} -> yield=14.53, cost=0.049
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=8.06, cost=0.445
# 📝 准备将第 9 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 9 轮建议 1 已加入先验数据
#    ✅ 第 9 轮建议 2 已加入先验数据
#    ✅ 第 9 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 32 个
# 📈 第 9 轮最佳结果: yield=14.53, cost=0.039
#
# 📋 第 9 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'PPhMe2', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'P(fur)3', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 90}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#
# 🔍 检查第 9 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=0.00%, cost=0.0392
#   建议 2 - 在数据集中找到: yield=14.53%, cost=0.0488
#   建议 3 - 在数据集中找到: yield=8.06%, cost=0.4447
#
# === 第 10 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 32 个
#    最近 5 个实验的产率: ['5.36', '5.29', '0.00', '14.53', '8.06']
#    最近 5 个实验的成本: ['0.3584', '0.3654', '0.0392', '0.0488', '0.4447']
#    🔍 检查上一轮（第 9 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=0.00, cost=0.0392)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=14.53, cost=0.0488)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=8.06, cost=0.4447)
# 🔧 创建 LLINBO Agent，使用 32 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 32 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120} -> yield=6.87, cost=0.358
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 105} -> yield=5.47, cost=0.146
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120} -> yield=54.52, cost=0.094
# 📝 准备将第 10 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 10 轮建议 1 已加入先验数据
#    ✅ 第 10 轮建议 2 已加入先验数据
#    ✅ 第 10 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 35 个
# 📈 第 10 轮最佳结果: yield=54.52, cost=0.094
#
# 📋 第 10 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 105}
#   建议 3: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 120}
#
# 🔍 检查第 10 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=6.87%, cost=0.3582
#   建议 2 - 在数据集中找到: yield=5.47%, cost=0.1458
#   建议 3 - 在数据集中找到: yield=54.52%, cost=0.0943
#
# === 第 11 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 35 个
#    最近 5 个实验的产率: ['14.53', '8.06', '6.87', '5.47', '54.52']
#    最近 5 个实验的成本: ['0.0488', '0.4447', '0.3582', '0.1458', '0.0943']
#    🔍 检查上一轮（第 10 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=6.87, cost=0.3582)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=5.47, cost=0.1458)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=54.52, cost=0.0943)
# 🔧 创建 LLINBO Agent，使用 35 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 35 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=5.36, cost=0.358
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120} -> yield=0.89, cost=0.140
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90} -> yield=57.95, cost=0.122
# 📝 准备将第 11 轮的 3 个实验结果加入到先验数据中
#    ⚠️ 第 11 轮建议 1 的参数组合已存在于先验数据中，跳过重复添加
#    ✅ 第 11 轮建议 2 已加入先验数据
#    ✅ 第 11 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 37 个
# 📈 第 11 轮最佳结果: yield=57.95, cost=0.122
#
# 📋 第 11 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#   建议 2: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 120}
#   建议 3: {'base': 'CsOAc', 'ligand': 'CgMe-PPh', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 90}
#
# 🔍 检查第 11 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=5.36%, cost=0.3584
#   建议 2 - 在数据集中找到: yield=0.89%, cost=0.1400
#   建议 3 - 在数据集中找到: yield=57.95%, cost=0.1215
#
# === 第 12 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 37 个
#    最近 5 个实验的产率: ['6.87', '5.47', '54.52', '0.89', '57.95']
#    最近 5 个实验的成本: ['0.3582', '0.1458', '0.0943', '0.1400', '0.1215']
#    🔍 检查上一轮（第 11 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=5.36, cost=0.3584)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=0.89, cost=0.1400)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=57.95, cost=0.1215)
# 🔧 创建 LLINBO Agent，使用 37 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 37 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=87.59, cost=0.057
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105} -> yield=22.30, cost=0.153
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105} -> yield=6.96, cost=0.457
# 📝 准备将第 12 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 12 轮建议 1 已加入先验数据
#    ✅ 第 12 轮建议 2 已加入先验数据
#    ✅ 第 12 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 40 个
# 📈 第 12 轮最佳结果: yield=87.59, cost=0.057
#
# 📋 第 12 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.057, 'temperature': 105}
#
# 🔍 检查第 12 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=87.59%, cost=0.0569
#   建议 2 - 在数据集中找到: yield=22.30%, cost=0.1533
#   建议 3 - 在数据集中找到: yield=6.96%, cost=0.4565
#
# === 第 13 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 40 个
#    最近 5 个实验的产率: ['0.89', '57.95', '87.59', '22.30', '6.96']
#    最近 5 个实验的成本: ['0.1400', '0.1215', '0.0569', '0.1533', '0.4565']
#    🔍 检查上一轮（第 12 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=87.59, cost=0.0569)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=22.30, cost=0.1533)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=6.96, cost=0.4565)
# 🔧 创建 LLINBO Agent，使用 40 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 40 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120} -> yield=70.26, cost=0.355
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'PPh3', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105} -> yield=4.51, cost=0.030
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90} -> yield=59.27, cost=0.083
# 📝 准备将第 13 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 13 轮建议 1 已加入先验数据
#    ✅ 第 13 轮建议 2 已加入先验数据
#    ✅ 第 13 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 43 个
# 📈 第 13 轮最佳结果: yield=70.26, cost=0.030
#
# 📋 第 13 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'PPh3', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90}
#
# 🔍 检查第 13 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=70.26%, cost=0.3551
#   建议 2 - 在数据集中找到: yield=4.51%, cost=0.0295
#   建议 3 - 在数据集中找到: yield=59.27%, cost=0.0825
#
# === 第 14 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 43 个
#    最近 5 个实验的产率: ['22.30', '6.96', '70.26', '4.51', '59.27']
#    最近 5 个实验的成本: ['0.1533', '0.4565', '0.3551', '0.0295', '0.0825']
#    🔍 检查上一轮（第 13 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=70.26, cost=0.3551)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=4.51, cost=0.0295)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=59.27, cost=0.0825)
# 🔧 创建 LLINBO Agent，使用 43 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 43 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=16.47, cost=0.373
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=13.85, cost=0.143
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 105} -> yield=89.17, cost=0.090
# 📝 准备将第 14 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 14 轮建议 1 已加入先验数据
#    ✅ 第 14 轮建议 2 已加入先验数据
#    ✅ 第 14 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 46 个
# 📈 第 14 轮最佳结果: yield=89.17, cost=0.090
#
# 📋 第 14 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90}
#   建议 3: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 105}
#
# 🔍 检查第 14 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=16.47%, cost=0.3729
#   建议 2 - 在数据集中找到: yield=13.85%, cost=0.1427
#   建议 3 - 在数据集中找到: yield=89.17%, cost=0.0904
#
# === 第 15 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 46 个
#    最近 5 个实验的产率: ['4.51', '59.27', '16.47', '13.85', '89.17']
#    最近 5 个实验的成本: ['0.0295', '0.0825', '0.3729', '0.1427', '0.0904']
#    🔍 检查上一轮（第 14 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=16.47, cost=0.3729)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=13.85, cost=0.1427)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=89.17, cost=0.0904)
# 🔧 创建 LLINBO Agent，使用 46 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 46 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=73.71, cost=0.047
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=0.74, cost=0.140
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=8.89, cost=0.445
# 📝 准备将第 15 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 15 轮建议 1 已加入先验数据
#    ✅ 第 15 轮建议 2 已加入先验数据
#    ✅ 第 15 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 49 个
# 📈 第 15 轮最佳结果: yield=73.71, cost=0.047
#
# 📋 第 15 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120}
#
# 🔍 检查第 15 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=73.71%, cost=0.0466
#   建议 2 - 在数据集中找到: yield=0.74%, cost=0.1400
#   建议 3 - 在数据集中找到: yield=8.89%, cost=0.4447
#
# === 第 16 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 49 个
#    最近 5 个实验的产率: ['13.85', '89.17', '73.71', '0.74', '8.89']
#    最近 5 个实验的成本: ['0.1427', '0.0904', '0.0466', '0.1400', '0.4447']
#    🔍 检查上一轮（第 15 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=73.71, cost=0.0466)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=0.74, cost=0.1400)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=8.89, cost=0.4447)
# 🔧 创建 LLINBO Agent，使用 49 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 49 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.280
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 90} -> yield=24.05, cost=0.364
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105} -> yield=21.54, cost=0.235
# 📝 准备将第 16 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 16 轮建议 1 已加入先验数据
#    ✅ 第 16 轮建议 2 已加入先验数据
#    ✅ 第 16 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 52 个
# 📈 第 16 轮最佳结果: yield=24.05, cost=0.235
#
# 📋 第 16 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'tBPh-CPhos', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.153, 'temperature': 90}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 105}
#
# 🔍 检查第 16 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=0.00%, cost=0.2795
#   建议 2 - 在数据集中找到: yield=24.05%, cost=0.3635
#   建议 3 - 在数据集中找到: yield=21.54%, cost=0.2345
#
# === 第 17 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 52 个
#    最近 5 个实验的产率: ['0.74', '8.89', '0.00', '24.05', '21.54']
#    最近 5 个实验的成本: ['0.1400', '0.4447', '0.2795', '0.3635', '0.2345']
#    🔍 检查上一轮（第 16 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=0.00, cost=0.2795)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=24.05, cost=0.3635)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=21.54, cost=0.2345)
# 🔧 创建 LLINBO Agent，使用 52 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 52 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 105} -> yield=56.14, cost=0.052
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90} -> yield=6.73, cost=0.353
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120} -> yield=0.00, cost=0.242
# 📝 准备将第 17 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 17 轮建议 1 已加入先验数据
#    ✅ 第 17 轮建议 2 已加入先验数据
#    ✅ 第 17 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 55 个
# 📈 第 17 轮最佳结果: yield=56.14, cost=0.052
#
# 📋 第 17 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'X-Phos', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 105}
#   建议 2: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 90}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'DMAc', 'concentration': 0.057, 'temperature': 120}
#
# 🔍 检查第 17 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=56.14%, cost=0.0516
#   建议 2 - 在数据集中找到: yield=6.73%, cost=0.3530
#   建议 3 - 在数据集中找到: yield=0.00%, cost=0.2423
#
# === 第 18 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 55 个
#    最近 5 个实验的产率: ['24.05', '21.54', '56.14', '6.73', '0.00']
#    最近 5 个实验的成本: ['0.3635', '0.2345', '0.0516', '0.3530', '0.2423']
#    🔍 检查上一轮（第 17 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=56.14, cost=0.0516)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=6.73, cost=0.3530)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=0.00, cost=0.2423)
# 🔧 创建 LLINBO Agent，使用 55 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 55 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120} -> yield=0.00, cost=0.043
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105} -> yield=63.88, cost=0.352
# ✅ 找到完全匹配: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90} -> yield=19.39, cost=0.235
# 📝 准备将第 18 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 18 轮建议 1 已加入先验数据
#    ✅ 第 18 轮建议 2 已加入先验数据
#    ✅ 第 18 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 58 个
# 📈 第 18 轮最佳结果: yield=63.88, cost=0.043
#
# 📋 第 18 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'PCy3 HBF4', 'solvent': 'BuOAc', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 105}
#   建议 3: {'base': 'CsOPiv', 'ligand': 'BrettPhos', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 90}
#
# 🔍 检查第 18 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=0.00%, cost=0.0428
#   建议 2 - 在数据集中找到: yield=63.88%, cost=0.3515
#   建议 3 - 在数据集中找到: yield=19.39%, cost=0.2345
#
# === 第 19 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 58 个
#    最近 5 个实验的产率: ['6.73', '0.00', '0.00', '63.88', '19.39']
#    最近 5 个实验的成本: ['0.3530', '0.2423', '0.0428', '0.3515', '0.2345']
#    🔍 检查上一轮（第 18 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=0.00, cost=0.0428)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=63.88, cost=0.3515)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=19.39, cost=0.2345)
# 🔧 创建 LLINBO Agent，使用 58 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 58 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105} -> yield=7.61, cost=0.353
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120} -> yield=70.51, cost=0.075
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90} -> yield=82.21, cost=0.084
# 📝 准备将第 19 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 19 轮建议 1 已加入先验数据
#    ✅ 第 19 轮建议 2 已加入先验数据
#    ✅ 第 19 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 61 个
# 📈 第 19 轮最佳结果: yield=82.21, cost=0.075
#
# 📋 第 19 轮生成的建议详情:
#   建议 1: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'p-Xylene', 'concentration': 0.153, 'temperature': 105}
#   建议 2: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'BuCN', 'concentration': 0.1, 'temperature': 120}
#   建议 3: {'base': 'CsOAc', 'ligand': 'X-Phos', 'solvent': 'BuOAc', 'concentration': 0.153, 'temperature': 90}
#
# 🔍 检查第 19 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=7.61%, cost=0.3530
#   建议 2 - 在数据集中找到: yield=70.51%, cost=0.0750
#   建议 3 - 在数据集中找到: yield=82.21%, cost=0.0836
#
# === 第 20 轮：LLINBO 优化 ===
# 📊 当前先验实验数据数量: 61 个
#    最近 5 个实验的产率: ['63.88', '19.39', '7.61', '70.51', '82.21']
#    最近 5 个实验的成本: ['0.3515', '0.2345', '0.3530', '0.0750', '0.0836']
#    🔍 检查上一轮（第 19 轮）的结果是否在先验数据中:
#       上一轮建议 1: ✅ 已在先验数据中 (yield=7.61, cost=0.3530)
#       上一轮建议 2: ✅ 已在先验数据中 (yield=70.51, cost=0.0750)
#       上一轮建议 3: ✅ 已在先验数据中 (yield=82.21, cost=0.0836)
# 🔧 创建 LLINBO Agent，使用 61 个先验实验数据
# ✅ Agent 创建完成，Agent 中的先验数据数量: 61 个
# 🤖 使用 LLINBO Agent 生成 3 个优化建议...
# 🤖 正在使用大模型生成优化建议...
# ✅ 成功生成 3 个建议
# ✅ 找到完全匹配: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120} -> yield=40.85, cost=0.059
# ✅ 找到完全匹配: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105} -> yield=24.09, cost=0.397
# ✅ 找到完全匹配: {'base': 'CsOAc', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90} -> yield=31.85, cost=0.067
# 📝 准备将第 20 轮的 3 个实验结果加入到先验数据中
#    ✅ 第 20 轮建议 1 已加入先验数据
#    ✅ 第 20 轮建议 2 已加入先验数据
#    ✅ 第 20 轮建议 3 已加入先验数据
# 📊 更新后的先验数据总数: 64 个
# 📈 第 20 轮最佳结果: yield=40.85, cost=0.059
#
# 📋 第 20 轮生成的建议详情:
#   建议 1: {'base': 'KOPiv', 'ligand': 'CgMe-PPh', 'solvent': 'p-Xylene', 'concentration': 0.1, 'temperature': 120}
#   建议 2: {'base': 'KOAc', 'ligand': 'JackiePhos', 'solvent': 'BuCN', 'concentration': 0.057, 'temperature': 105}
#   建议 3: {'base': 'CsOAc', 'ligand': 'PPh3', 'solvent': 'DMAc', 'concentration': 0.153, 'temperature': 90}
#
# 🔍 检查第 20 轮建议是否在原始数据集中:
#   建议 1 - 在数据集中找到: yield=40.85%, cost=0.0591
#   建议 2 - 在数据集中找到: yield=24.09%, cost=0.3969
#   建议 3 - 在数据集中找到: yield=31.85%, cost=0.0672

# %%
import pandas as pd
# 设置 pandas 显示选项，显示所有行和列
pd.set_option('display.max_columns', None)  # 显示所有列
pd.set_option('display.max_rows', None)     # 显示所有行
pd.set_option('display.width', None)        # 不限制显示宽度
pd.set_option('display.max_colwidth', None) # 不限制列宽度


experiments_df = pd.DataFrame([{
    **exp.parameters,
    **exp.metrics

} for exp in llinbo_experiments])
experiments_df
# Out:
#       base           ligand   solvent  concentration  temperature  yield  \
# 0    CsOAc             PPh3      BuCN          0.100           90   5.80
# 1    CsOAc        BrettPhos      BuCN          0.153           90  28.02
# 2   CsOPiv  GorlosPhos HBF4  p-Xylene          0.153          105   4.53
# 3     KOAc           X-Phos      DMAc          0.057          120  77.58
# 4    KOPiv          P(fur)3      BuCN          0.153          120  53.11
# 5    CsOAc        PCy3 HBF4     BuOAc          0.057          105   0.00
# 6   CsOPiv         CgMe-PPh     BuOAc          0.100          105  24.00
# 7    KOPiv       tBPh-CPhos  p-Xylene          0.153           90  24.02
# 8    KOPiv           PPh2Me      DMAc          0.057           90   5.02
# 9     KOAc          PPhtBu2      DMAc          0.057          120   2.13
# 10   KOPiv       JackiePhos     BuOAc          0.100          120   6.73
# 11    KOAc           PPhMe2  p-Xylene          0.057          105   0.00
# 12  CsOPiv           X-Phos      DMAc          0.153           90  27.79
# 13    KOAc       JackiePhos     BuOAc          0.100          120   7.82
# 14   KOPiv         CgMe-PPh  p-Xylene          0.100          105  32.37
# 15  CsOPiv             PPh3      DMAc          0.057          120  84.64
# 16    KOAc         CgMe-PPh  p-Xylene          0.100          120  46.75
# 17   KOPiv       JackiePhos      DMAc          0.153          105  11.68
# 18   CsOAc           PPhMe2     BuOAc          0.100          105   0.00
# 19   KOPiv        BrettPhos      DMAc          0.057          105   0.00
# 20  CsOPiv       JackiePhos     BuOAc          0.153           90   2.77
# 21    KOAc        BrettPhos      DMAc          0.153          120   5.95
# 22  CsOPiv       JackiePhos      BuCN          0.100           90  13.01
# 23    KOAc           PPh2Me      DMAc          0.100          120  10.51
# 24   KOPiv         CgMe-PPh  p-Xylene          0.153          105  31.32
# 25  CsOPiv       JackiePhos     BuOAc          0.100          105   2.41
# 26   KOPiv  GorlosPhos HBF4     BuOAc          0.100          120  35.43
# 27    KOAc       JackiePhos  p-Xylene          0.100          105   5.36
# 28  CsOPiv       tBPh-CPhos      DMAc          0.057           90   5.29
# 29   KOPiv           PPhMe2     BuOAc          0.100          120   0.00
# 30    KOAc          P(fur)3      DMAc          0.057           90  14.53
# 31  CsOPiv       JackiePhos  p-Xylene          0.100          105   8.06
# 32   KOPiv       JackiePhos     BuOAc          0.153          120   6.87
# 33    KOAc        BrettPhos      DMAc          0.100          105   5.47
# 34   CsOAc           X-Phos  p-Xylene          0.057          120  54.52
# 35   KOPiv        BrettPhos      DMAc          0.153          120   0.89
# 36   CsOAc         CgMe-PPh      BuCN          0.100           90  57.95
# 37   KOPiv         CgMe-PPh      DMAc          0.100          120  87.59
# 38    KOAc        BrettPhos      BuCN          0.153          105  22.30
# 39  CsOPiv       JackiePhos  p-Xylene          0.057          105   6.96
# 40   KOPiv       JackiePhos      DMAc          0.100          120  70.26
# 41    KOAc             PPh3     BuOAc          0.153          105   4.51
# 42   CsOAc           X-Phos  p-Xylene          0.100           90  59.27
# 43   KOPiv       JackiePhos      BuCN          0.100          120  16.47
# 44    KOAc        BrettPhos  p-Xylene          0.153           90  13.85
# 45   CsOAc           X-Phos      DMAc          0.057          105  89.17
# 46    KOAc           X-Phos     BuOAc          0.100          120  73.71
# 47   KOPiv        BrettPhos      DMAc          0.153          105   0.74
# 48  CsOPiv       JackiePhos  p-Xylene          0.100          120   8.89
# 49   KOPiv       tBPh-CPhos     BuOAc          0.100          120   0.00
# 50    KOAc       JackiePhos      BuCN          0.153           90  24.05
# 51  CsOPiv        BrettPhos  p-Xylene          0.100          105  21.54
# 52   KOPiv           X-Phos      BuCN          0.100          105  56.14
# 53    KOAc       JackiePhos  p-Xylene          0.153           90   6.73
# 54  CsOPiv        BrettPhos      DMAc          0.057          120   0.00
# 55   KOPiv        PCy3 HBF4     BuOAc          0.100          120   0.00
# 56    KOAc       JackiePhos      DMAc          0.153          105  63.88
# 57  CsOPiv        BrettPhos  p-Xylene          0.100           90  19.39
# 58    KOAc       JackiePhos  p-Xylene          0.153          105   7.61
# 59   KOPiv         CgMe-PPh      BuCN          0.100          120  70.51
# 60   CsOAc           X-Phos     BuOAc          0.153           90  82.21
# 61   KOPiv         CgMe-PPh  p-Xylene          0.100          120  40.85
# 62    KOAc       JackiePhos      BuCN          0.057          105  24.09
# 63   CsOAc             PPh3      DMAc          0.153           90  31.85
#
#         cost
# 0   0.089659
# 1   0.198802
# 2   0.121718
# 3   0.044840
# 4   0.045232
# 5   0.107935
# 6   0.155989
# 7   0.264828
# 8   0.036398
# 9   0.053335
# 10  0.366672
# 11  0.042701
# 12  0.116292
# 13  0.367772
# 14  0.059114
# 15  0.123037
# 16  0.060261
# 17  0.350300
# 18  0.085823
# 19  0.154793
# 20  0.445596
# 21  0.141126
# 22  0.460307
# 23  0.027381
# 24  0.053706
# 25  0.454115
# 26  0.049227
# 27  0.358358
# 28  0.365429
# 29  0.039229
# 30  0.048762
# 31  0.444741
# 32  0.358151
# 33  0.145775
# 34  0.094283
# 35  0.140017
# 36  0.121531
# 37  0.056922
# 38  0.153257
# 39  0.456505
# 40  0.355120
# 41  0.029512
# 42  0.082532
# 43  0.372866
# 44  0.142733
# 45  0.090374
# 46  0.046620
# 47  0.140017
# 48  0.444744
# 49  0.279535
# 50  0.363522
# 51  0.234539
# 52  0.051648
# 53  0.352959
# 54  0.242261
# 55  0.042782
# 56  0.351545
# 57  0.234531
# 58  0.352962
# 59  0.075033
# 60  0.083647
# 61  0.059145
# 62  0.396877
# 63  0.067234
